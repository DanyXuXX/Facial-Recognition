# %% [markdown]
# # <center><font size=10>人脸识别</font></center>

# %% [markdown]
# # <span id='content'>目录</span>
#
# ## [一、课前回顾](#一)
#
# ## [二、卷积神经网络之应用--人脸识别](#二)
#
# ### [- 1. 人脸识别简介](#二-1)
#
# ### [- 2. 人脸识别两大问题：人脸认证、人脸识别](#二-2)
#
# ### [- 3. 进行人脸认证的一种简单思路](#二-3)
#
# ### [- 4. 使用卷积神经网络进行人脸认证的流程概括](#二-4)
#
# ## [三、人脸识别流程详细说明](#三)
#
# ### [- 1. 迁移学习](#三-1)
#
# ### [- 2. 举例：用VGG16模型进行编码](#三-2)
#
# ### [- 3. LFW数据库](#三-3)
#
# ### [- 4. 通过比对两张图片的编码进行人脸认证](#三-4)
#
# ### [- 5. 阈值的确定](#三-5)
#
# ### [- 6. 三元组代价函数--一种在人脸识别领域应用广泛且有效的损失函数](#三-6)
#
# ### [- 7. MTCNN](#三-7)
#
# ## [四、大作业：班级人脸识别项目](#四)

# %% [markdown]
# # <span id='一'>一、课前回顾</span>
#
# 上一课中，我们已经开始用卷积神经网络进行图片分类，已经了解了如下知识点：
#
# - convolution：相关概念filter, padding, channel
# - batch normalization 批规范化：通过对每一层的输出规范为均值和方差一致的方法，消除了w带来的放大缩小的影响。
# - pooling: max vs. average
# - 激活函数：softmax, Relu, Sigmoid

# %% [markdown]
# # <span id='二'>二、卷积神经网络之应用--人脸识别</span>
#
# 卷积神经网络最重要的应用之一是人脸识别，这一课我们就用卷积神经网络来处理人脸图片。
#
#
# ## <span id='二-1'>1. 人脸识别简介</span>
# - 定义：
#  - 广义的人脸识别实际包括构建人脸识别系统的一系列相关技术，包括人脸图像采集、人脸定位或检测、人脸识别预处理、身份确认以及身份查找等；
#  - 而狭义的人脸识别特指通过人脸进行身份确认或者身份查找的技术或系统。
# - 人脸识别的一般处理流程：
#  - 图像获取：人脸图像通过摄像镜头获取得到；
#  - 人脸检测：在图像中标定出人脸的位置和大小，自动估计脸部特征的坐标；
#  - 人脸图像预处理：由于原始图像往往受到光照、角度等条件的限制和干扰，故须在图像处理的早期阶段对其进行灰度矫正、噪声过滤等预处理。
#    - 常用预处理方法有 ：灰度变化、归一化、直方图均衡、中值滤波等；
#  - 人脸特征提取：可通过嵌入向量的方法提取出有助于人脸分类的特征数据；
#  - 比对识别：两张人脸图片经一系列操作后可进行对比识别；
#  - 输出结果：判断两张人脸图片是否属于同一人。
#
#   如下图所示：
#
# <img style = "float:left" src = "辅助图片/人脸识别流程.jpg">

# %% [markdown]
# ## <span id='二-2'>2. 人脸识别两大问题：人脸认证、人脸识别</span>
#
# #### (1). 人脸识别：
# 首先拥有多人图像数据库，然后输入一张不在数据库中的人脸图像，目标是判断此人是否在数据库中，是的话并找到对应的那个人。是1：N问题。
#
# 注：人脸认证和人脸识别也可统称为人脸识别，本课在不混淆意思的前提下会统称为人脸识别。
#
# #### (2). 人脸认证：
# 输入人脸图像，并指定数据库中要比对的人，目标是判断两张人脸图像是否属于同一个人，是1：1问题。
#
#
# #### (3). 二者对比：
# |  |  人脸认证   | 人脸识别  |
# | :----  |  :----  | :----  |
# | 输出  | 认证的信心度  | 最相似的人脸以及信心度 |
# | 实现要求  |    在手机配置上就可以实现得很好  | 对于计算和存储的要求更高 |
# | 成功要求  | 很低的false positive  | 很低的false positive和false negative |
#
#
#
# 就二者的难度来说，人脸识别要比人脸认证难得多：
#
# 假设一个认证系统的准确率是99%，把这个认证系统应用到有100个人数据库的人脸识别上，犯错的机会就会乘以100。所以如果有一个上百人的数据库，并且想得到一个可接受的人脸识别误差，首先构造的人脸认证系统就需要99.9%，甚至更高的准确率才行。
#
# 我们可以考虑首先构造一个人脸认证系统作为基本模块，进行处理之后，再把它应用到人脸识别系统上。
#
#
# ## <span id='二-3'>3. 进行人脸认证的一种简单思路</span>
# 对于人脸认证，最简单的思路是：
# 拿到两张人脸图像，直接比较两张图像中所有像素值的差别，取其加和。若该值小于事先确定的阈值，则可以认为他们是同一个人。
#
# >思考：这样做会存在什么问题吗？
#
# 答：比对过程会受到非人脸部分的影响，即色彩、亮度、环境等都会使两张的图像的像素值之差不准确。例如，同一个人的照片加个滤镜可能就认不出来了。同时，同一个人不同角度的图片也会在像素值上有天翻地覆的差别，从而影响结果。
#
# >思考：那么能否从图像中剔除这些影响，只找到与人脸外形相关的特征，然后进行比对？
#
# 答：对于受到非人脸环境的影响问题，可参照人脸识别处理流程中的预处理步骤，对图片进行预处理；而对于同人不同角度等问题造成的识别精度不够这种情况，则提醒我们要寻求一个更精准识别人脸的方法。
#
# 也就是本课的主题：运用卷积神经网络识别人脸。
#
# ## <span id='二-4'>4. 使用卷积神经网络进行人脸认证的流程概括</span>
#
# 卷积神经网络分别以两张图片作为输入，然后输出这两张图片的编码（即特征向量）。如果你放进同一个人的两张照片，你希望最后输出的两个编码之间的距离很小，如果放进两个长相差别很大的人的照片，就希望距离很大。
#
# 所以在人脸认证过程中，需要人为确定一个阈值。如果这两张图片的距离小于某个阈值，那么这时就能预测这两张图片是同一个人，如果距离大于阈值，就能预测这是不同的两个人。
#
# ***
# >现在让我们开始我们的人脸识别之旅吧！
#
# 首先导入本课程所需要的库以及运行所需要的各项准备：
# ***

# %%
import os
import torchvision.models as models
from PIL import Image, ImageDraw
import datetime
from torch.autograd import Variable
import torch
import cv2
import numpy as np
from facenet_pytorch import MTCNN, extract_face
import matplotlib.pyplot as plt
device = 'cpu'

# %% [markdown]
# ### <span id='三'>三、人脸识别流程详细说明</span>
#
# >首先，我们学习如何将人脸图片进行编码。
#
# 卷积神经网络（CNN）常用来为人脸图片编码。例如，VGG就是这样一个为图像编码的CNN模型，其效果如下图所示：
#
# <img src = "辅助图片/VGG编码.jpg">
#
#
# >人脸图片的编码完成后，我们会利用编码来完成一系列功能。这是一个迁移学习过程。

# %% [markdown]
# ## <span id='三-1'>1. 迁移学习</span>
# >吴恩达：“迁移学习将会是继监督学习之后的下一个机器学习商业成功的驱动力。”
#
# - 出现背景：
#  - 目前的深度学习只有在拥有充足的标注数据时才能达到很好的准确率。
#  - 海量数据下的模型训练需要非常大的算力。普通人：臣妾做不到啊~
#
# - 思想：将旧领域的模型应用在新领域上，从而加快并优化模型的学习效率。
#
# - 具体做法：利用在大数据集上预先训练好的神经网络来初始化网络（而不是随机初始化），然后根据自己的目标任务需求，可选择通过微调等操作对这个神经网络的结构进行改动，并在自己的数据集上进行进一步的训练。
#
# - 核心问题：
#  - 如何合理地寻找不同领域之间的相似性，从而利用相似性，将已有模型应用到新的不同的、但有一定关联的领域中。
#  - 如何对使用的预训练模型进行适用于自己目标任务的改动。
#
# - 例如：
#   在自然语言处理领域中，预训练模型BERT的语义表达效果非常好。输入一句话，BERT可以生成这句话的嵌入向量（即用数字向量的形式来表达这句话），距离相近的向量对应的原句的意思也是相近的。我们在BERT模型的基础上，给这个神经网络再加上一个头部，如加上全连接层来作为分类器，就可以把输入的文本做分类，从而应用到如情感分析等具体任务上。
#
#
# 本课我们使用VGG16模型为例，展示一下图片的编码结果。鼓励同学们在进行大作业的编写时，通过查找和对比效果来选择其他效果更好的模型，并可选择结合迁移学习知识，使模型效果更佳。
#
# ## <span id='三-2'>2. 举例：用VGG16模型进行编码</span>
#
# #### 选取两张图片，进行大小调整，使其符合VGG16模型的输入要求

# %%
# 为了能够读写带中文路径的图片，重新定义cv2的读写函数
def cv2_imread(file_path):
    cv_img = cv2.imdecode(np.fromfile(file_path, dtype=np.uint8), -1)
    return cv_img


def cv2_imwrite(path, img):
    cv2.imencode('.jpg', img)[1].tofile(path)

img1 = cv2_imread("李小强.jpg")
new_img1 = cv2.resize(img1, (224, 224))
cv2_imwrite("preprocessed李小强.jpg", new_img1)

img2 = cv2_imread("张小二.jpg")
new_img2 = cv2.resize(img2, (224, 224))
cv2_imwrite("preprocessed张小二.jpg", new_img2)

# %% [markdown]
# #### 将图片格式修改为可以直接输入模型的张量格式，然后调用训练好的VGG模型，输出图片通过模型前后的格式。

# %%
# 定义函数，将图片转成张量格式
def tensor_convert_vgg(img_path):
    img = cv2_imread(img_path)
    batch = img.reshape(1, 3, 224, 224)
    tensor = torch.from_numpy(batch).float().to(device)
    return tensor

img1_name = "preprocessed李小强.jpg"
img2_name = "preprocessed张小二.jpg"


tensor1 = tensor_convert_vgg("preprocessed李小强.jpg")
tensor2 = tensor_convert_vgg("preprocessed张小二.jpg")

vgg = models.vgg16(pretrained=True).eval().to(device)

result1 = vgg(Variable(tensor1))
result2 = vgg(Variable(tensor2))

print("李小强：\n", "  vgg16模型输入大小为: ", list(tensor1.size()),
      "; 输出大小为: ", list(result1.size()))
print("张小二：\n", "  vgg16模型输入大小为: ", list(tensor2.size()),
      "; 输出大小为: ", list(result2.size()))
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to C:\Users\Lenovo/.cache\torch\hub\checkpoints\vgg16-397923af.pth
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-25394b79f946> in <module>
#      13 tensor2 = tensor_convert_vgg("preprocessed张小二.jpg")
#      14
# ---> 15 vgg = models.vgg16(pretrained=True).eval().to(device)
#      16
#      17 result1 = vgg(Variable(tensor1))
#
# D:\Software\anaconda\lib\site-packages\torchvision\models\vgg.py in vgg16(pretrained, progress, **kwargs)
#     155         progress (bool): If True, displays a progress bar of the download to stderr
#     156     """
# --> 157     return _vgg('vgg16', 'D', False, pretrained, progress, **kwargs)
#     158
#     159
#
# D:\Software\anaconda\lib\site-packages\torchvision\models\vgg.py in _vgg(arch, cfg, batch_norm, pretrained, progress, **kwargs)
#      97     model = VGG(make_layers(cfgs[cfg], batch_norm=batch_norm), **kwargs)
#      98     if pretrained:
# ---> 99         state_dict = load_state_dict_from_url(model_urls[arch],
#     100                                               progress=progress)
#     101         model.load_state_dict(state_dict)
#
# D:\Software\anaconda\lib\site-packages\torch\hub.py in load_state_dict_from_url(url, model_dir, map_location, progress, check_hash, file_name)
#     522             r = HASH_REGEX.search(filename)  # r is Optional[Match[str]]
#     523             hash_prefix = r.group(1) if r else None
# --> 524         download_url_to_file(url, cached_file, hash_prefix, progress=progress)
#     525
#     526     if _is_legacy_zip_format(cached_file):
#
# D:\Software\anaconda\lib\site-packages\torch\hub.py in download_url_to_file(url, dst, hash_prefix, progress)
#     414                   unit='B', unit_scale=True, unit_divisor=1024) as pbar:
#     415             while True:
# --> 416                 buffer = u.read(8192)
#     417                 if len(buffer) == 0:
#     418                     break
#
# D:\Software\anaconda\lib\http\client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# D:\Software\anaconda\lib\http\client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# D:\Software\anaconda\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# D:\Software\anaconda\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# D:\Software\anaconda\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# 若运行结果正确，我们可以看到，通过VGG模型前，两张图像的大小为\[1, 3, 224, 224]，分别对应\[样本数, 图像通道数, 图像高度, 图像宽度]。通过VGG模型后，两张图像变成了两个1000维的特征向量。
#
# #### (4). 注意事项：
# 同学们在进行实验时，要先明确好自己选择的模型的输入是什么格式，以免出错。

# %% [markdown]
# >上述应用的两张图片都是从LFW数据集中选取的。
#
# ## <span id='三-3'>3. LFW数据库</span>
#
# LFW (Labeled Faces in the Wild)人脸数据库主要用于研究非受限情况下的人脸识别问题。共含有13000多张人脸图像，其主要来源是互联网。每张图像都被标识出对应的人的名字，大约其中的1680人包含两个以上的人脸。
#
# LFW数据库可用于测试人脸识别的准确率，该数据库随机选择了6000对人脸组成了人脸辨识图片对，其中3000对属于同一人，3000对属于不同的人。测试过程中，LFW数据库随机给出一对图片，询问测试中的系统这两张图片是不是同一个人，系统给出“是”或“否”的答案。通过6000对人脸测试结果的系统答案与真实答案的比值，可以得到系统的人脸识别准确率。
#
# [LFW数据库传送门](http://vis-www.cs.umass.edu/lfw/)
# ***
# >现在我们的第一步已经完成，即已经将图像编好码了。接下来就是要对比两张图片。
#
# ## <span id='三-4'>4. 通过比对两张图片的编码进行人脸认证</span>
#
# **实际上，对比两张图片就是要对比图片对应的编码向量的距离（如欧几里得距离），如下图所示。**
#
# <img src = "辅助图片/两人距离.jpg">
#
# >进行人脸认证时，要确定两张图片是否是同一张人脸，需要事先确定一个阈值，当两张图片的距离小于阈值时，模型认为图片是同一张人脸；当距离大于阈值时，认为是不同的人脸。那么，阈值该如何确定呢？
#
# ## <span id='三-5'>5. 阈值的确定</span>
# 加上阈值后，整个人脸识别流程如下图所示：
#
# <img style = "float:left" src = "辅助图片/两人距离有阈值.jpg">
#
# 对于阈值的确定没有数学上的计算方法，而通常是通过尝试，根据经验选择。在确定阈值的过程中，往往要事先确定好一个范围，并通过不断地在多个图像组上的测试，来缩小这个范围，最终在错误率最低的那个范围中选取一个值作为最终的阈值。
#
# ***
#
#
# ## <span id='三-6'>6. 三元组代价函数--一种在人脸识别领域应用广泛且有效的损失函数</span>
#
# 我们本课直接使用了VGG16预训练模型做例，但是用户可以根据自己的需求进行模型选择或者在原模型基础上进行改进。比如在训练过程中，我们可以改为在人脸识别领域效果更好的三元组代价函数（Triplet Loss），然后再通过梯度下降来更新网络中的权重。
#
# #### (1). 三元组是什么：
# - 样本组成：三张图片：
#  - 靶目标(Anchor)，简写为 $A$.
#  - 正例(Positive)，简写为 $P$.
#  - 反例(Negative)，简写为 $N$.
# - 样本要求：靶目标和正例是同一个人，和反例不是同一个人。
# - 目的：在定义了这些包括$A、P、N$图片的数据集后，用梯度下降最小化代价函数，使得$A$和$P$之间的距离很小，而$A$和$N$之间的距离很大。
# - 效果：通过改变神经网络中的权重，最终得到一个优秀的特征向量，使得相似的图像在向量空间是相近的，可以借此判断是否是同一个人的人脸。
#
# 三元组代价函数的效果图如下：
#
# <img style = "float:left" src = "辅助图片/三元代价函数效果图.jpg">

# %% [markdown]
# #### (2). 三元组代价函数（Triplet Loss）的推导：
# 设图片A的编码为$f(A)$，图片P的编码是$f(P)$，图片N的编码是$f(N)$，我们希望靶目标A和正例图片P的间距小于靶目标和反例图片N的间距，即：
#
# $$\|f(A)-f(P)\|^{2} \leq\|f(A)-f(N)\|^{2}$$
#
# $$\|f(A)-f(P)\|^{2}-\|f(A)-F(N)\|^{2} \leq 0$$
#
# 但是这样还不够，比如当 $d(A,P)=0.5$, $d(A,N)=0.51$ 的时候，虽然满足了要求，但是二者之间的距离差很小，这样训练得到的结果不能很好地区分相似的图像，因此为了增强算法的鲁棒性，我们引入一个超参数 $\alpha$，将上述不等式修改为：
#
# $$\|f(A)-f(P)\|^{2}-\|f(A)-f(N)\|^{2} \leq-\alpha$$
#
# $$\|f(A)-f(P)\|^{2}-\|f(A)-F(N)\|^{2}+\alpha \leq 0$$
#
# 超参数 $\alpha$ 类似于支持向量机中的margin，目的就是要拼命拉近靶目标和正例之间的距离、拉远靶目标和反例之间的距离。
#
# 同时，$\alpha$ 值的选取也是一门学问：过小的话会将所有图像映射到极小区域范围内的向量空间，不能很好地区分；过大的话loss值会很难趋近于零，训练时间会无限延长。
#
# ***
# 综上，三元组代价函数是基于上述三元图片组的，定义为：
#
# $$L(A, P, N)=\max \left(\|f(A)-f(P)\|^{2}-\|f(A)-f(N)\|^{2}+\alpha, 0\right)$$
#
# 在代价函数中，取两项中的最大值，我们要尽可能的使 $\|f(A)-f(P)\|^{2}-\|f(A)-f(N)\|^{2}+\alpha$ 这一项为0，或者小于0，这样这组三元组得到的代价值就为0；如果前一项大于0，得到的代价值就会大于0.
#
# 整个网络的代价函数就是训练集中每个三元组代价的总和，若共有M个三元组，则整个网络的三元代价函数为：
#
# $$J=\sum_{i=1}^{M} L\left(A^{(i)}, P^{(i)}, N^{(i)}\right)$$

# %% [markdown]
# #### (3). 如何选择三元组来构成训练集？
#
# 你可能觉得，随机选择是最好的方法。但是实际上，这样的话约束条件 $d(A, P)+\alpha \leq d(A, N)$ 就会很容易实现。因为随机选择的图片，$A$ 和 $N$ 比 $A$ 和 $P$ 差别很大的概率不算小，这样的话网络并不能从中学习到什么。
#
# 所以，为了构建一个更有效的数据集，要做的就是尽可能选择难训练的三元组 $A$、 $P$ 和 $N$。 即要想使得所有三元组都满足条件
# $d(A, P)+a \leq d(A, N)$ ，应选择最接近的 $d(A, P)$ 和 $d(A, N)$，这样学习算法会竭尽全力使得 $d(A, N)$ 变大，或者使得 $d(A, P)$
# 变小，这样选择可以增加学习算法的计算效率。
#
#
# >以上代码全是根据数据集中的照片进行操作的，如果提供日常中拍出的照片，进行人脸识别，会出现什么问题呢？
#
# ## <span id='三-7'>7. MTCNN</span>
#
# 我们知道，数据集中的照片都是经过加工之后的，是专门用来训练或者测试模型的。但是日常拍照并非如此，普通照片中，人的身体和周围环境往往被照进镜头从而导致人脸识别误差增大。
#
# 此时，我们需要进行一系列操作，使得机器能够自动截取照片上的人脸，然后再送去编码识别。
#
# **MTCNN就是干这个的。**
#
# MTCNN（多任务卷积神经网络）中的"MT"是指多任务学习(Multi-Task)，同时学习“识别人脸”、“人脸边框回归”、“人脸关键点识别”；"CNN"是指卷积神经网络(Convolutional Neural Network)。MTCNN是由中国科学院提出的用于人脸检测任务的多任务神经网络模型，可进行快速高效的人脸检测。
#
# 我们来尝试使用MTCNN，看看它的作用效果。

# %%
mtcnn = MTCNN(keep_all=True)
img = Image.open("test1.jpg")
boxes, probs, points = mtcnn.detect(img, landmarks=True)
img_draw = img.copy()
draw = ImageDraw.Draw(img_draw)
for i, (box, point) in enumerate(zip(boxes, points)):
    draw.rectangle(box.tolist(), width=5)
    for p in point:
        draw.rectangle((p-10).tolist()+(p+10).tolist(), width=10)
    extract_face(img, box, save_path='detect_face_{}.png'.format(i))
img_draw.save('annotated_faces.png')

# %% [markdown]
# 上面这个代码块使用同级目录下的名为"test1.jpg"的图片作为输入，将经过MTCNN人脸关键点标注后的结果进行可视化之后命名为"annotated_face.png"，保存在同级目录下，将MTCNN的截取结果命名为"detect_face_0.png"，保存在同级目录下。下面进行这三张图片的展示。

# %%
plt.figure()
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.4, top=0.9,
                wspace=0.2, hspace=0.2)
img = Image.open("test1.jpg")
ax = plt.subplot(1,3,1)
plt.imshow(img)
ax.set_title("Original Figure")

img = Image.open("annotated_faces.png")
ax = plt.subplot(1,3,2)
plt.imshow(img)
ax.set_title("Annotated By MTCNN")

img = Image.open("detect_face_0.png")
ax = plt.subplot(1,3,3)
plt.imshow(img)
ax.set_title("Cut By MTCNN")

plt.show()

# %% [markdown]
# 由上图我们可以看到，MTCNN可以识别一张图片中的人脸位置所在，同时定位到人脸关键点，包括眼、鼻、嘴。所以使用通过MTCNN截取后的人脸图片，我们可以使人脸识别不再受照片中环境等因素的影响，使得识别精度更高。
#
# 有感兴趣的同学可以去[这里](https://blog.csdn.net/qq_36782182/article/details/83624357?depth_1-utm_source=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-1&utm_source=distribute.pc_relevant.none-task-blog-BlogCommendFromBaidu-1)看一下MTCNN的具体架构和工作原理，此处不再多讲。
#
# >现在我们已经基本掌握了人脸识别和认所需的模型运用等知识，下面来进行大作业的编写吧！
#
# ### <span id='四'>四、大作业：班级人脸识别项目</span>
#
# 满足条件及注意事项：
# - 将所给人脸照片文件夹作为班级人脸数据库，其中每人有五张图片。
# - test文件下存储的是用来识别或认证的不属于数据库中的照片，每人有一张图片。
# - 将人脸识别的代码封装成一个函数，命名为facial_recognition，其输入是当前测试图片的路径，且函数要返回最相似的人的名字。
# - 将人脸认证的代码封装成一个函数，命名为facial_verification，其输入是数据库中想要比对的人脸id和当前的测试图片的路径，且函数要根据认证的结果，即返回字符串“True”或字符串“False”。
# - 定义人名列表，列表中每个元素是人名字符串（即类似于["张三", "李四"]），列表名为names，评测中用到的id值即为在names列表中的序号（从0开始）。
# - 最终考核结果标准是识别的准确率和时间，以及认证的四项标准。

# %%
#################################START OF YOUR HOMEWORK#################################
import torch
import numpy as np
import pandas as pd
import math
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from torch import optim
from facenet_pytorch import prewhiten
from torch.optim.lr_scheduler import MultiStepLR
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms
from facenet_pytorch import InceptionResnetV1,training, MTCNN, fixed_image_standardization
import os
import cv2
from torch.autograd import Variable
from PIL import Image, ImageDraw
import sys
workers = 0 if os.name == 'nt' else 8
device = 'cpu'

# %%
mtcnn = MTCNN(
    image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device
)

# %%
#定义mtcnn
mtCNN = MTCNN(
    image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device
)
dataset = datasets.ImageFolder('mydata_可切割图片',transform=transforms.Resize((1024, 1024)))
dataset.samples = [(p, p.replace('mydata_可切割图片', 'mydata_cut'))
        for p, _ in dataset.samples]        
loader = DataLoader(dataset,num_workers=workers,
                    batch_size = 32,collate_fn=training.collate_pil)


# 对数据库图片进行mtcnn处理并保存
for i, (x, y) in enumerate(loader):
    mtCNN(x, save_path=y)
    print('\rBatch {} of {}'.format(i + 1, len(loader)), end='')
# Out:
# Batch 2 of 8
# C:\Users\Lenovo\Desktop\58119213徐丹颖_人脸识别\无答案\facenet_pytorch\models\utils\detect_face.py:142: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   batch_boxes, batch_points = np.array(batch_boxes), np.array(batch_points)
# C:\Users\Lenovo\Desktop\58119213徐丹颖_人脸识别\无答案\facenet_pytorch\models\mtcnn.py:369: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   boxes = np.array(boxes)
# C:\Users\Lenovo\Desktop\58119213徐丹颖_人脸识别\无答案\facenet_pytorch\models\mtcnn.py:370: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   probs = np.array(probs)
# C:\Users\Lenovo\Desktop\58119213徐丹颖_人脸识别\无答案\facenet_pytorch\models\mtcnn.py:371: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   points = np.array(points)
# Batch 8 of 8

# %%
######################
#以上是数据集预处理
######################

# %%
data_dir = 'data'
batch_size = 25 
epochs = 8
device = torch.device( 'cpu')

# %%
resnet = InceptionResnetV1(
     classify=True,
     pretrained='vggface2',
     dropout_prob=0.8,
     num_classes=41,#班里有41位同学
).to(device)

# %%
#初始化模型后存为myresnet1.pt
torch.save(resnet,"myresnet1.pt")

# %%
#用1训练mytrain
#在此基础上使用finetune用自己的训练集进一步对模型优化

resnet=torch.load("myresnet1.pt")

optimizer = optim.Adam(resnet.parameters(), lr=0.001) 
scheduler = MultiStepLR(optimizer, [5, 10])
trans = transforms.Compose([
    transforms.RandomRotation(10),       #随机旋转
    transforms.ColorJitter(brightness=0.1,contrast=0.1,saturation=0.1),  #随机亮度对比度饱和度变换，增加图像数据量，防止过拟合
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])
dataset = datasets.ImageFolder('mytrain_cut', transform=trans)
#############
train_loader = DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True
)
print(len(train_loader))
##########
loss_fn = torch.nn.CrossEntropyLoss()

metrics = {
    'acc': training.accuracy
}
writer = SummaryWriter()
writer.iteration, writer.interval = 0, 10


for epoch in range(epochs):
    print('\nEpoch {}/{}'.format(epoch + 1, epochs))
    print('-' * 10)
    resnet.train()
    training.pass_epoch(
        resnet, loss_fn, train_loader, optimizer, scheduler,
        batch_metrics=metrics, show_running=True, device=device,
        writer=writer
    )
writer.close()

torch.save(resnet,"myresnet8.pt")
# Out:
# 9
#
# Epoch 1/8
# ----------
# Train |     1/9    | loss:    3.4753 | acc:    0.9600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-c987be7e681e> in <module>
#      35     print('-' * 10)
#      36     resnet.train()
# ---> 37     training.pass_epoch(
#      38         resnet, loss_fn, train_loader, optimizer, scheduler,
#      39         batch_metrics=metrics, show_running=True, device=device,
#
# ~\Desktop\ws\58119213徐丹颖_人脸识别\无答案\facenet_pytorch\models\utils\training.py in pass_epoch(model, loss_fn, loader, optimizer, scheduler, batch_metrics, show_running, device, writer)
#      93     metrics = {}
#      94
# ---> 95     for i_batch, (x, y) in enumerate(loader):
#      96         x = x.to(device)
#      97         y = y.to(device)
#
# D:\Software\anaconda\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# D:\Software\anaconda\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     555     def _next_data(self):
#     556         index = self._next_index()  # may raise StopIteration
# --> 557         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     558         if self._pin_memory:
#     559             data = _utils.pin_memory.pin_memory(data)
#
# D:\Software\anaconda\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# D:\Software\anaconda\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# D:\Software\anaconda\lib\site-packages\torchvision\datasets\folder.py in __getitem__(self, index)
#     178         sample = self.loader(path)
#     179         if self.transform is not None:
# --> 180             sample = self.transform(sample)
#     181         if self.target_transform is not None:
#     182             target = self.target_transform(target)
#
# D:\Software\anaconda\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# D:\Software\anaconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# D:\Software\anaconda\lib\site-packages\torchvision\transforms\transforms.py in forward(self, img)
#    1144
#    1145         for fn_id in fn_idx:
# -> 1146             if fn_id == 0 and brightness_factor is not None:
#    1147                 img = F.adjust_brightness(img, brightness_factor)
#    1148             elif fn_id == 1 and contrast_factor is not None:
#
# KeyboardInterrupt:

# %%
#mytest_cut 验证结果

# %%
#人脸识别识别函数与判断函数定义
from torch.autograd import Variable
from PIL import Image, ImageDraw
resnet=torch.load("myresnet_final_30.pt")
names=[]
trans = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])

for item in os.listdir('mydata_cut'):
    names.append(item[9:])

def facial_recognition(path):
    resnet.eval()
    img=Image.open(path)
    img_tensor=trans(img)
    img_tensor=Variable(img_tensor.unsqueeze(0))
    output=resnet(img_tensor)
    _, train_predicted = torch.max(output.data, 1)
    print(names[train_predicted.item()])
    return names[train_predicted.item()]



def facial_verification(id,path):
    print(names[id])
    if facial_recognition(path)==names[id]:
        return 'True'
    else:
        return 'False'

# %%
print(names)
# Out:
# ['蔡雅清', '方玉杰', '彭英哲', '闫海玉', '李佳祥', '廖宏祖', '陈智宏', '顾海健', '何远洋', '吕喆行', '朱宇飞', '蒋卓洋', '李柏萱', '李凯新', '袁一啸', '温若尧', '司考', '牟俊奇', '欧阳雨彤', '苏彤彤', '沈小力', '徐丹颖', '耿青青', '杨捷', '刘幽远', '沈洋洋', '吴东昊', '白云浩', '谢志林', '朱婷婷', '曾晗', '朱启鹏', '张静涵', '秦巧琳', '马添毅', '余江伟', '李雨辰', '刘誉飞', '罗卓彦', '王兆阳', '王湘源']

# %%
# 人脸识别评测代码    
import datetime

starttime = datetime.datetime.now()
right = 0
wrong = 0

for item in os.listdir("mytest_cut"):
    test_path = "mytest_cut"+"\\" + item
    print(item)
    if facial_recognition(test_path) in item:
        right += 1
    else:
        wrong += 1

accuracy = right / (right+wrong)
endtime = datetime.datetime.now()

print("人脸识别的考察结果：")
print("人脸识别的准确率是:", accuracy)
print("整个人脸识别的运行时间是：", (endtime-starttime).seconds, "s")
# Out:
# 何远洋_1.jpg
# 白云浩
# 余江伟_1.jpg
# 余江伟
# 刘幽远_1.jpg
# 刘幽远
# 刘誉飞_1.jpg
# 刘誉飞
# 司考_1.jpg
# 司考
# 吕喆行_1.jpg
# 罗卓彦
# 吴东昊_1.jpg
# 吴东昊
# 廖宏祖_1.jpg
# 沈小力
# 张静涵_1.jpg
# 张静涵
# 彭英哲_1.jpg
# 彭英哲
# 徐丹颖_1.jpg
# 徐丹颖
# 方玉杰_1.jpg
# 陈智宏
# 曾晗_1.jpg
# 曾晗
# 朱启鹏_1.jpg
# 朱启鹏
# 朱婷婷_1.jpg
# 朱婷婷
# 朱宇飞_1.jpg
# 朱宇飞
# 李佳祥_1.jpg
# 李佳祥
# 李凯新_1.jpg
# 李凯新
# 李柏萱_1.jpg
# 陈智宏
# 李雨辰_1.jpg
# 李雨辰
# 杨捷_1.JPG
# 欧阳雨彤
# 欧阳雨彤_1.jpg
# 欧阳雨彤
# 沈小力_1.jpg
# 沈小力
# 沈洋洋_1.jpg
# 牟俊奇
# 温若尧_1.JPG
# 温若尧
# 牟俊奇_1.jpg
# 沈洋洋
# 王兆阳_1.jpg
# 王兆阳
# 王湘源_1.jpg
# 王湘源
# 白云浩_1.jpg
# 刘幽远
# 秦巧琳_1.jpg
# 秦巧琳
# 罗卓彦_1.jpg
# 罗卓彦
# 耿青青_1.JPG
# 耿青青
# 苏彤彤_1.jpg
# 张静涵
# 蒋卓洋_1.jpg
# 陈智宏
# 蔡雅清_1.JPG
# 耿青青
# 袁一啸_1.jpg
# 杨捷
# 谢志林_1.jpg
# 谢志林
# 闫海玉_1.jpg
# 闫海玉
# 陈智宏_1.jpg
# 张静涵
# 顾海健_1.jpg
# 顾海健
# 马添毅_1.jpg
# 王湘源
# 人脸识别的考察结果：
# 人脸识别的准确率是: 0.6341463414634146
# 整个人脸识别的运行时间是： 4 s

# %%
# 人脸认证评测代码

tp = 0
tn = 0
fp = 0
fn = 0

for name in names:
    test_path = "mytest_cut/" + name + "_1.jpg"
    for id in range(len(names)):
        result = facial_verification(id, test_path)
        if name == names[id] and result == "True":
            tp +=1
        elif name == names[id] and result == "False":
            fn += 1
        elif name != names[id] and result == "False":
            tn += 1
        else:
            fp += 1

print("人脸认证的考察结果:")
print("精度:", tp/(tp+fp))
print("回归率:", tp/(tp+fn))
print("特异性:", tn/(tn+fp))
print("F1值:", 2*tp/(2*tp+fp+fn))
# Out:
# 蔡雅清
# 蔡雅清
# 方玉杰
# 蔡雅清
# 彭英哲
# 蔡雅清
# 闫海玉
# 蔡雅清
# 李佳祥
# 蔡雅清
# 廖宏祖
# 蔡雅清
# 陈智宏
# 蔡雅清
# 顾海健
# 蔡雅清
# 何远洋
# 蔡雅清
# 吕喆行
# 蔡雅清
# 朱宇飞
# 蔡雅清
# 蒋卓洋
# 蔡雅清
# 李柏萱
# 蔡雅清
# 李凯新
# 蔡雅清
# 袁一啸
# 蔡雅清
# 温若尧
# 蔡雅清
# 司考
# 蔡雅清
# 牟俊奇
# 蔡雅清
# 欧阳雨彤
# 蔡雅清
# 苏彤彤
# 蔡雅清
# 沈小力
# 蔡雅清
# 徐丹颖
# 蔡雅清
# 耿青青
# 蔡雅清
# 杨捷
# 蔡雅清
# 刘幽远
# 蔡雅清
# 沈洋洋
# 蔡雅清
# 吴东昊
# 蔡雅清
# 白云浩
# 蔡雅清
# 谢志林
# 蔡雅清
# 朱婷婷
# 蔡雅清
# 曾晗
# 蔡雅清
# 朱启鹏
# 蔡雅清
# 张静涵
# 蔡雅清
# 秦巧琳
# 蔡雅清
# 马添毅
# 蔡雅清
# 余江伟
# 蔡雅清
# 李雨辰
# 蔡雅清
# 刘誉飞
# 蔡雅清
# 罗卓彦
# 蔡雅清
# 王兆阳
# 蔡雅清
# 王湘源
# 蔡雅清
# 蔡雅清
# 方玉杰
# 方玉杰
# 方玉杰
# 彭英哲
# 方玉杰
# 闫海玉
# 方玉杰
# 李佳祥
# 方玉杰
# 廖宏祖
# 方玉杰
# 陈智宏
# 方玉杰
# 顾海健
# 方玉杰
# 何远洋
# 方玉杰
# 吕喆行
# 方玉杰
# 朱宇飞
# 方玉杰
# 蒋卓洋
# 方玉杰
# 李柏萱
# 方玉杰
# 李凯新
# 方玉杰
# 袁一啸
# 方玉杰
# 温若尧
# 方玉杰
# 司考
# 方玉杰
# 牟俊奇
# 方玉杰
# 欧阳雨彤
# 方玉杰
# 苏彤彤
# 方玉杰
# 沈小力
# 方玉杰
# 徐丹颖
# 方玉杰
# 耿青青
# 方玉杰
# 杨捷
# 方玉杰
# 刘幽远
# 方玉杰
# 沈洋洋
# 方玉杰
# 吴东昊
# 方玉杰
# 白云浩
# 方玉杰
# 谢志林
# 方玉杰
# 朱婷婷
# 方玉杰
# 曾晗
# 方玉杰
# 朱启鹏
# 方玉杰
# 张静涵
# 方玉杰
# 秦巧琳
# 方玉杰
# 马添毅
# 方玉杰
# 余江伟
# 方玉杰
# 李雨辰
# 方玉杰
# 刘誉飞
# 方玉杰
# 罗卓彦
# 方玉杰
# 王兆阳
# 方玉杰
# 王湘源
# 方玉杰
# 蔡雅清
# 彭英哲
# 方玉杰
# 彭英哲
# 彭英哲
# 彭英哲
# 闫海玉
# 彭英哲
# 李佳祥
# 彭英哲
# 廖宏祖
# 彭英哲
# 陈智宏
# 彭英哲
# 顾海健
# 彭英哲
# 何远洋
# 彭英哲
# 吕喆行
# 彭英哲
# 朱宇飞
# 彭英哲
# 蒋卓洋
# 彭英哲
# 李柏萱
# 彭英哲
# 李凯新
# 彭英哲
# 袁一啸
# 彭英哲
# 温若尧
# 彭英哲
# 司考
# 彭英哲
# 牟俊奇
# 彭英哲
# 欧阳雨彤
# 彭英哲
# 苏彤彤
# 彭英哲
# 沈小力
# 彭英哲
# 徐丹颖
# 彭英哲
# 耿青青
# 彭英哲
# 杨捷
# 彭英哲
# 刘幽远
# 彭英哲
# 沈洋洋
# 彭英哲
# 吴东昊
# 彭英哲
# 白云浩
# 彭英哲
# 谢志林
# 彭英哲
# 朱婷婷
# 彭英哲
# 曾晗
# 彭英哲
# 朱启鹏
# 彭英哲
# 张静涵
# 彭英哲
# 秦巧琳
# 彭英哲
# 马添毅
# 彭英哲
# 余江伟
# 彭英哲
# 李雨辰
# 彭英哲
# 刘誉飞
# 彭英哲
# 罗卓彦
# 彭英哲
# 王兆阳
# 彭英哲
# 王湘源
# 彭英哲
# 蔡雅清
# 闫海玉
# 方玉杰
# 闫海玉
# 彭英哲
# 闫海玉
# 闫海玉
# 闫海玉
# 李佳祥
# 闫海玉
# 廖宏祖
# 闫海玉
# 陈智宏
# 闫海玉
# 顾海健
# 闫海玉
# 何远洋
# 闫海玉
# 吕喆行
# 闫海玉
# 朱宇飞
# 闫海玉
# 蒋卓洋
# 闫海玉
# 李柏萱
# 闫海玉
# 李凯新
# 闫海玉
# 袁一啸
# 闫海玉
# 温若尧
# 闫海玉
# 司考
# 闫海玉
# 牟俊奇
# 闫海玉
# 欧阳雨彤
# 闫海玉
# 苏彤彤
# 闫海玉
# 沈小力
# 闫海玉
# 徐丹颖
# 闫海玉
# 耿青青
# 闫海玉
# 杨捷
# 闫海玉
# 刘幽远
# 闫海玉
# 沈洋洋
# 闫海玉
# 吴东昊
# 闫海玉
# 白云浩
# 闫海玉
# 谢志林
# 闫海玉
# 朱婷婷
# 闫海玉
# 曾晗
# 闫海玉
# 朱启鹏
# 闫海玉
# 张静涵
# 闫海玉
# 秦巧琳
# 闫海玉
# 马添毅
# 闫海玉
# 余江伟
# 闫海玉
# 李雨辰
# 闫海玉
# 刘誉飞
# 闫海玉
# 罗卓彦
# 闫海玉
# 王兆阳
# 闫海玉
# 王湘源
# 闫海玉
# 蔡雅清
# 李佳祥
# 方玉杰
# 李佳祥
# 彭英哲
# 李佳祥
# 闫海玉
# 李佳祥
# 李佳祥
# 李佳祥
# 廖宏祖
# 李佳祥
# 陈智宏
# 李佳祥
# 顾海健
# 李佳祥
# 何远洋
# 李佳祥
# 吕喆行
# 李佳祥
# 朱宇飞
# 李佳祥
# 蒋卓洋
# 李佳祥
# 李柏萱
# 李佳祥
# 李凯新
# 李佳祥
# 袁一啸
# 李佳祥
# 温若尧
# 李佳祥
# 司考
# 李佳祥
# 牟俊奇
# 李佳祥
# 欧阳雨彤
# 李佳祥
# 苏彤彤
# 李佳祥
# 沈小力
# 李佳祥
# 徐丹颖
# 李佳祥
# 耿青青
# 李佳祥
# 杨捷
# 李佳祥
# 刘幽远
# 李佳祥
# 沈洋洋
# 李佳祥
# 吴东昊
# 李佳祥
# 白云浩
# 李佳祥
# 谢志林
# 李佳祥
# 朱婷婷
# 李佳祥
# 曾晗
# 李佳祥
# 朱启鹏
# 李佳祥
# 张静涵
# 李佳祥
# 秦巧琳
# 李佳祥
# 马添毅
# 李佳祥
# 余江伟
# 李佳祥
# 李雨辰
# 李佳祥
# 刘誉飞
# 李佳祥
# 罗卓彦
# 李佳祥
# 王兆阳
# 李佳祥
# 王湘源
# 李佳祥
# 蔡雅清
# 廖宏祖
# 方玉杰
# 廖宏祖
# 彭英哲
# 廖宏祖
# 闫海玉
# 廖宏祖
# 李佳祥
# 廖宏祖
# 廖宏祖
# 廖宏祖
# 陈智宏
# 廖宏祖
# 顾海健
# 廖宏祖
# 何远洋
# 廖宏祖
# 吕喆行
# 廖宏祖
# 朱宇飞
# 廖宏祖
# 蒋卓洋
# 廖宏祖
# 李柏萱
# 廖宏祖
# 李凯新
# 廖宏祖
# 袁一啸
# 廖宏祖
# 温若尧
# 廖宏祖
# 司考
# 廖宏祖
# 牟俊奇
# 廖宏祖
# 欧阳雨彤
# 廖宏祖
# 苏彤彤
# 廖宏祖
# 沈小力
# 廖宏祖
# 徐丹颖
# 廖宏祖
# 耿青青
# 廖宏祖
# 杨捷
# 廖宏祖
# 刘幽远
# 廖宏祖
# 沈洋洋
# 廖宏祖
# 吴东昊
# 廖宏祖
# 白云浩
# 廖宏祖
# 谢志林
# 廖宏祖
# 朱婷婷
# 廖宏祖
# 曾晗
# 廖宏祖
# 朱启鹏
# 廖宏祖
# 张静涵
# 廖宏祖
# 秦巧琳
# 廖宏祖
# 马添毅
# 廖宏祖
# 余江伟
# 廖宏祖
# 李雨辰
# 廖宏祖
# 刘誉飞
# 廖宏祖
# 罗卓彦
# 廖宏祖
# 王兆阳
# 廖宏祖
# 王湘源
# 廖宏祖
# 蔡雅清
# 陈智宏
# 方玉杰
# 陈智宏
# 彭英哲
# 陈智宏
# 闫海玉
# 陈智宏
# 李佳祥
# 陈智宏
# 廖宏祖
# 陈智宏
# 陈智宏
# 陈智宏
# 顾海健
# 陈智宏
# 何远洋
# 陈智宏
# 吕喆行
# 陈智宏
# 朱宇飞
# 陈智宏
# 蒋卓洋
# 陈智宏
# 李柏萱
# 陈智宏
# 李凯新
# 陈智宏
# 袁一啸
# 陈智宏
# 温若尧
# 陈智宏
# 司考
# 陈智宏
# 牟俊奇
# 陈智宏
# 欧阳雨彤
# 陈智宏
# 苏彤彤
# 陈智宏
# 沈小力
# 陈智宏
# 徐丹颖
# 陈智宏
# 耿青青
# 陈智宏
# 杨捷
# 陈智宏
# 刘幽远
# 陈智宏
# 沈洋洋
# 陈智宏
# 吴东昊
# 陈智宏
# 白云浩
# 陈智宏
# 谢志林
# 陈智宏
# 朱婷婷
# 陈智宏
# 曾晗
# 陈智宏
# 朱启鹏
# 陈智宏
# 张静涵
# 陈智宏
# 秦巧琳
# 陈智宏
# 马添毅
# 陈智宏
# 余江伟
# 陈智宏
# 李雨辰
# 陈智宏
# 刘誉飞
# 陈智宏
# 罗卓彦
# 陈智宏
# 王兆阳
# 陈智宏
# 王湘源
# 陈智宏
# 蔡雅清
# 顾海健
# 方玉杰
# 顾海健
# 彭英哲
# 顾海健
# 闫海玉
# 顾海健
# 李佳祥
# 顾海健
# 廖宏祖
# 顾海健
# 陈智宏
# 顾海健
# 顾海健
# 顾海健
# 何远洋
# 顾海健
# 吕喆行
# 顾海健
# 朱宇飞
# 顾海健
# 蒋卓洋
# 顾海健
# 李柏萱
# 顾海健
# 李凯新
# 顾海健
# 袁一啸
# 顾海健
# 温若尧
# 顾海健
# 司考
# 顾海健
# 牟俊奇
# 顾海健
# 欧阳雨彤
# 顾海健
# 苏彤彤
# 顾海健
# 沈小力
# 顾海健
# 徐丹颖
# 顾海健
# 耿青青
# 顾海健
# 杨捷
# 顾海健
# 刘幽远
# 顾海健
# 沈洋洋
# 顾海健
# 吴东昊
# 顾海健
# 白云浩
# 顾海健
# 谢志林
# 顾海健
# 朱婷婷
# 顾海健
# 曾晗
# 顾海健
# 朱启鹏
# 顾海健
# 张静涵
# 顾海健
# 秦巧琳
# 顾海健
# 马添毅
# 顾海健
# 余江伟
# 顾海健
# 李雨辰
# 顾海健
# 刘誉飞
# 顾海健
# 罗卓彦
# 顾海健
# 王兆阳
# 顾海健
# 王湘源
# 顾海健
# 蔡雅清
# 王湘源
# 方玉杰
# 王湘源
# 彭英哲
# 王湘源
# 闫海玉
# 王湘源
# 李佳祥
# 王湘源
# 廖宏祖
# 王湘源
# 陈智宏
# 王湘源
# 顾海健
# 王湘源
# 何远洋
# 王湘源
# 吕喆行
# 王湘源
# 朱宇飞
# 王湘源
# 蒋卓洋
# 王湘源
# 李柏萱
# 王湘源
# 李凯新
# 王湘源
# 袁一啸
# 王湘源
# 温若尧
# 王湘源
# 司考
# 王湘源
# 牟俊奇
# 王湘源
# 欧阳雨彤
# 王湘源
# 苏彤彤
# 王湘源
# 沈小力
# 王湘源
# 徐丹颖
# 王湘源
# 耿青青
# 王湘源
# 杨捷
# 王湘源
# 刘幽远
# 王湘源
# 沈洋洋
# 王湘源
# 吴东昊
# 王湘源
# 白云浩
# 王湘源
# 谢志林
# 王湘源
# 朱婷婷
# 王湘源
# 曾晗
# 王湘源
# 朱启鹏
# 王湘源
# 张静涵
# 王湘源
# 秦巧琳
# 王湘源
# 马添毅
# 王湘源
# 余江伟
# 王湘源
# 李雨辰
# 王湘源
# 刘誉飞
# 王湘源
# 罗卓彦
# 王湘源
# 王兆阳
# 王湘源
# 王湘源
# 王湘源
# 蔡雅清
# 吕喆行
# 方玉杰
# 吕喆行
# 彭英哲
# 吕喆行
# 闫海玉
# 吕喆行
# 李佳祥
# 吕喆行
# 廖宏祖
# 吕喆行
# 陈智宏
# 吕喆行
# 顾海健
# 吕喆行
# 何远洋
# 吕喆行
# 吕喆行
# 吕喆行
# 朱宇飞
# 吕喆行
# 蒋卓洋
# 吕喆行
# 李柏萱
# 吕喆行
# 李凯新
# 吕喆行
# 袁一啸
# 吕喆行
# 温若尧
# 吕喆行
# 司考
# 吕喆行
# 牟俊奇
# 吕喆行
# 欧阳雨彤
# 吕喆行
# 苏彤彤
# 吕喆行
# 沈小力
# 吕喆行
# 徐丹颖
# 吕喆行
# 耿青青
# 吕喆行
# 杨捷
# 吕喆行
# 刘幽远
# 吕喆行
# 沈洋洋
# 吕喆行
# 吴东昊
# 吕喆行
# 白云浩
# 吕喆行
# 谢志林
# 吕喆行
# 朱婷婷
# 吕喆行
# 曾晗
# 吕喆行
# 朱启鹏
# 吕喆行
# 张静涵
# 吕喆行
# 秦巧琳
# 吕喆行
# 马添毅
# 吕喆行
# 余江伟
# 吕喆行
# 李雨辰
# 吕喆行
# 刘誉飞
# 吕喆行
# 罗卓彦
# 吕喆行
# 王兆阳
# 吕喆行
# 王湘源
# 吕喆行
# 蔡雅清
# 朱宇飞
# 方玉杰
# 朱宇飞
# 彭英哲
# 朱宇飞
# 闫海玉
# 朱宇飞
# 李佳祥
# 朱宇飞
# 廖宏祖
# 朱宇飞
# 陈智宏
# 朱宇飞
# 顾海健
# 朱宇飞
# 何远洋
# 朱宇飞
# 吕喆行
# 朱宇飞
# 朱宇飞
# 朱宇飞
# 蒋卓洋
# 朱宇飞
# 李柏萱
# 朱宇飞
# 李凯新
# 朱宇飞
# 袁一啸
# 朱宇飞
# 温若尧
# 朱宇飞
# 司考
# 朱宇飞
# 牟俊奇
# 朱宇飞
# 欧阳雨彤
# 朱宇飞
# 苏彤彤
# 朱宇飞
# 沈小力
# 朱宇飞
# 徐丹颖
# 朱宇飞
# 耿青青
# 朱宇飞
# 杨捷
# 朱宇飞
# 刘幽远
# 朱宇飞
# 沈洋洋
# 朱宇飞
# 吴东昊
# 朱宇飞
# 白云浩
# 朱宇飞
# 谢志林
# 朱宇飞
# 朱婷婷
# 朱宇飞
# 曾晗
# 朱宇飞
# 朱启鹏
# 朱宇飞
# 张静涵
# 朱宇飞
# 秦巧琳
# 朱宇飞
# 马添毅
# 朱宇飞
# 余江伟
# 朱宇飞
# 李雨辰
# 朱宇飞
# 刘誉飞
# 朱宇飞
# 罗卓彦
# 朱宇飞
# 王兆阳
# 朱宇飞
# 王湘源
# 朱宇飞
# 蔡雅清
# 蒋卓洋
# 方玉杰
# 蒋卓洋
# 彭英哲
# 蒋卓洋
# 闫海玉
# 蒋卓洋
# 李佳祥
# 蒋卓洋
# 廖宏祖
# 蒋卓洋
# 陈智宏
# 蒋卓洋
# 顾海健
# 蒋卓洋
# 何远洋
# 蒋卓洋
# 吕喆行
# 蒋卓洋
# 朱宇飞
# 蒋卓洋
# 蒋卓洋
# 蒋卓洋
# 李柏萱
# 蒋卓洋
# 李凯新
# 蒋卓洋
# 袁一啸
# 蒋卓洋
# 温若尧
# 蒋卓洋
# 司考
# 蒋卓洋
# 牟俊奇
# 蒋卓洋
# 欧阳雨彤
# 蒋卓洋
# 苏彤彤
# 蒋卓洋
# 沈小力
# 蒋卓洋
# 徐丹颖
# 蒋卓洋
# 耿青青
# 蒋卓洋
# 杨捷
# 蒋卓洋
# 刘幽远
# 蒋卓洋
# 沈洋洋
# 蒋卓洋
# 吴东昊
# 蒋卓洋
# 白云浩
# 蒋卓洋
# 谢志林
# 蒋卓洋
# 朱婷婷
# 蒋卓洋
# 曾晗
# 蒋卓洋
# 朱启鹏
# 蒋卓洋
# 张静涵
# 蒋卓洋
# 秦巧琳
# 蒋卓洋
# 马添毅
# 蒋卓洋
# 余江伟
# 蒋卓洋
# 李雨辰
# 蒋卓洋
# 刘誉飞
# 蒋卓洋
# 罗卓彦
# 蒋卓洋
# 王兆阳
# 蒋卓洋
# 王湘源
# 蒋卓洋
# 蔡雅清
# 曾晗
# 方玉杰
# 曾晗
# 彭英哲
# 曾晗
# 闫海玉
# 曾晗
# 李佳祥
# 曾晗
# 廖宏祖
# 曾晗
# 陈智宏
# 曾晗
# 顾海健
# 曾晗
# 何远洋
# 曾晗
# 吕喆行
# 曾晗
# 朱宇飞
# 曾晗
# 蒋卓洋
# 曾晗
# 李柏萱
# 曾晗
# 李凯新
# 曾晗
# 袁一啸
# 曾晗
# 温若尧
# 曾晗
# 司考
# 曾晗
# 牟俊奇
# 曾晗
# 欧阳雨彤
# 曾晗
# 苏彤彤
# 曾晗
# 沈小力
# 曾晗
# 徐丹颖
# 曾晗
# 耿青青
# 曾晗
# 杨捷
# 曾晗
# 刘幽远
# 曾晗
# 沈洋洋
# 曾晗
# 吴东昊
# 曾晗
# 白云浩
# 曾晗
# 谢志林
# 曾晗
# 朱婷婷
# 曾晗
# 曾晗
# 曾晗
# 朱启鹏
# 曾晗
# 张静涵
# 曾晗
# 秦巧琳
# 曾晗
# 马添毅
# 曾晗
# 余江伟
# 曾晗
# 李雨辰
# 曾晗
# 刘誉飞
# 曾晗
# 罗卓彦
# 曾晗
# 王兆阳
# 曾晗
# 王湘源
# 曾晗
# 蔡雅清
# 李凯新
# 方玉杰
# 李凯新
# 彭英哲
# 李凯新
# 闫海玉
# 李凯新
# 李佳祥
# 李凯新
# 廖宏祖
# 李凯新
# 陈智宏
# 李凯新
# 顾海健
# 李凯新
# 何远洋
# 李凯新
# 吕喆行
# 李凯新
# 朱宇飞
# 李凯新
# 蒋卓洋
# 李凯新
# 李柏萱
# 李凯新
# 李凯新
# 李凯新
# 袁一啸
# 李凯新
# 温若尧
# 李凯新
# 司考
# 李凯新
# 牟俊奇
# 李凯新
# 欧阳雨彤
# 李凯新
# 苏彤彤
# 李凯新
# 沈小力
# 李凯新
# 徐丹颖
# 李凯新
# 耿青青
# 李凯新
# 杨捷
# 李凯新
# 刘幽远
# 李凯新
# 沈洋洋
# 李凯新
# 吴东昊
# 李凯新
# 白云浩
# 李凯新
# 谢志林
# 李凯新
# 朱婷婷
# 李凯新
# 曾晗
# 李凯新
# 朱启鹏
# 李凯新
# 张静涵
# 李凯新
# 秦巧琳
# 李凯新
# 马添毅
# 李凯新
# 余江伟
# 李凯新
# 李雨辰
# 李凯新
# 刘誉飞
# 李凯新
# 罗卓彦
# 李凯新
# 王兆阳
# 李凯新
# 王湘源
# 李凯新
# 蔡雅清
# 杨捷
# 方玉杰
# 杨捷
# 彭英哲
# 杨捷
# 闫海玉
# 杨捷
# 李佳祥
# 杨捷
# 廖宏祖
# 杨捷
# 陈智宏
# 杨捷
# 顾海健
# 杨捷
# 何远洋
# 杨捷
# 吕喆行
# 杨捷
# 朱宇飞
# 杨捷
# 蒋卓洋
# 杨捷
# 李柏萱
# 杨捷
# 李凯新
# 杨捷
# 袁一啸
# 杨捷
# 温若尧
# 杨捷
# 司考
# 杨捷
# 牟俊奇
# 杨捷
# 欧阳雨彤
# 杨捷
# 苏彤彤
# 杨捷
# 沈小力
# 杨捷
# 徐丹颖
# 杨捷
# 耿青青
# 杨捷
# 杨捷
# 杨捷
# 刘幽远
# 杨捷
# 沈洋洋
# 杨捷
# 吴东昊
# 杨捷
# 白云浩
# 杨捷
# 谢志林
# 杨捷
# 朱婷婷
# 杨捷
# 曾晗
# 杨捷
# 朱启鹏
# 杨捷
# 张静涵
# 杨捷
# 秦巧琳
# 杨捷
# 马添毅
# 杨捷
# 余江伟
# 杨捷
# 李雨辰
# 杨捷
# 刘誉飞
# 杨捷
# 罗卓彦
# 杨捷
# 王兆阳
# 杨捷
# 王湘源
# 杨捷
# 蔡雅清
# 温若尧
# 方玉杰
# 温若尧
# 彭英哲
# 温若尧
# 闫海玉
# 温若尧
# 李佳祥
# 温若尧
# 廖宏祖
# 温若尧
# 陈智宏
# 温若尧
# 顾海健
# 温若尧
# 何远洋
# 温若尧
# 吕喆行
# 温若尧
# 朱宇飞
# 温若尧
# 蒋卓洋
# 温若尧
# 李柏萱
# 温若尧
# 李凯新
# 温若尧
# 袁一啸
# 温若尧
# 温若尧
# 温若尧
# 司考
# 温若尧
# 牟俊奇
# 温若尧
# 欧阳雨彤
# 温若尧
# 苏彤彤
# 温若尧
# 沈小力
# 温若尧
# 徐丹颖
# 温若尧
# 耿青青
# 温若尧
# 杨捷
# 温若尧
# 刘幽远
# 温若尧
# 沈洋洋
# 温若尧
# 吴东昊
# 温若尧
# 白云浩
# 温若尧
# 谢志林
# 温若尧
# 朱婷婷
# 温若尧
# 曾晗
# 温若尧
# 朱启鹏
# 温若尧
# 张静涵
# 温若尧
# 秦巧琳
# 温若尧
# 马添毅
# 温若尧
# 余江伟
# 温若尧
# 李雨辰
# 温若尧
# 刘誉飞
# 温若尧
# 罗卓彦
# 温若尧
# 王兆阳
# 温若尧
# 王湘源
# 温若尧
# 蔡雅清
# 司考
# 方玉杰
# 司考
# 彭英哲
# 司考
# 闫海玉
# 司考
# 李佳祥
# 司考
# 廖宏祖
# 司考
# 陈智宏
# 司考
# 顾海健
# 司考
# 何远洋
# 司考
# 吕喆行
# 司考
# 朱宇飞
# 司考
# 蒋卓洋
# 司考
# 李柏萱
# 司考
# 李凯新
# 司考
# 袁一啸
# 司考
# 温若尧
# 司考
# 司考
# 司考
# 牟俊奇
# 司考
# 欧阳雨彤
# 司考
# 苏彤彤
# 司考
# 沈小力
# 司考
# 徐丹颖
# 司考
# 耿青青
# 司考
# 杨捷
# 司考
# 刘幽远
# 司考
# 沈洋洋
# 司考
# 吴东昊
# 司考
# 白云浩
# 司考
# 谢志林
# 司考
# 朱婷婷
# 司考
# 曾晗
# 司考
# 朱启鹏
# 司考
# 张静涵
# 司考
# 秦巧琳
# 司考
# 马添毅
# 司考
# 余江伟
# 司考
# 李雨辰
# 司考
# 刘誉飞
# 司考
# 罗卓彦
# 司考
# 王兆阳
# 司考
# 王湘源
# 司考
# 蔡雅清
# 牟俊奇
# 方玉杰
# 牟俊奇
# 彭英哲
# 牟俊奇
# 闫海玉
# 牟俊奇
# 李佳祥
# 牟俊奇
# 廖宏祖
# 牟俊奇
# 陈智宏
# 牟俊奇
# 顾海健
# 牟俊奇
# 何远洋
# 牟俊奇
# 吕喆行
# 牟俊奇
# 朱宇飞
# 牟俊奇
# 蒋卓洋
# 牟俊奇
# 李柏萱
# 牟俊奇
# 李凯新
# 牟俊奇
# 袁一啸
# 牟俊奇
# 温若尧
# 牟俊奇
# 司考
# 牟俊奇
# 牟俊奇
# 牟俊奇
# 欧阳雨彤
# 牟俊奇
# 苏彤彤
# 牟俊奇
# 沈小力
# 牟俊奇
# 徐丹颖
# 牟俊奇
# 耿青青
# 牟俊奇
# 杨捷
# 牟俊奇
# 刘幽远
# 牟俊奇
# 沈洋洋
# 牟俊奇
# 吴东昊
# 牟俊奇
# 白云浩
# 牟俊奇
# 谢志林
# 牟俊奇
# 朱婷婷
# 牟俊奇
# 曾晗
# 牟俊奇
# 朱启鹏
# 牟俊奇
# 张静涵
# 牟俊奇
# 秦巧琳
# 牟俊奇
# 马添毅
# 牟俊奇
# 余江伟
# 牟俊奇
# 李雨辰
# 牟俊奇
# 刘誉飞
# 牟俊奇
# 罗卓彦
# 牟俊奇
# 王兆阳
# 牟俊奇
# 王湘源
# 牟俊奇
# 蔡雅清
# 欧阳雨彤
# 方玉杰
# 欧阳雨彤
# 彭英哲
# 欧阳雨彤
# 闫海玉
# 欧阳雨彤
# 李佳祥
# 欧阳雨彤
# 廖宏祖
# 欧阳雨彤
# 陈智宏
# 欧阳雨彤
# 顾海健
# 欧阳雨彤
# 何远洋
# 欧阳雨彤
# 吕喆行
# 欧阳雨彤
# 朱宇飞
# 欧阳雨彤
# 蒋卓洋
# 欧阳雨彤
# 李柏萱
# 欧阳雨彤
# 李凯新
# 欧阳雨彤
# 袁一啸
# 欧阳雨彤
# 温若尧
# 欧阳雨彤
# 司考
# 欧阳雨彤
# 牟俊奇
# 欧阳雨彤
# 欧阳雨彤
# 欧阳雨彤
# 苏彤彤
# 欧阳雨彤
# 沈小力
# 欧阳雨彤
# 徐丹颖
# 欧阳雨彤
# 耿青青
# 欧阳雨彤
# 杨捷
# 欧阳雨彤
# 刘幽远
# 欧阳雨彤
# 沈洋洋
# 欧阳雨彤
# 吴东昊
# 欧阳雨彤
# 白云浩
# 欧阳雨彤
# 谢志林
# 欧阳雨彤
# 朱婷婷
# 欧阳雨彤
# 曾晗
# 欧阳雨彤
# 朱启鹏
# 欧阳雨彤
# 张静涵
# 欧阳雨彤
# 秦巧琳
# 欧阳雨彤
# 马添毅
# 欧阳雨彤
# 余江伟
# 欧阳雨彤
# 李雨辰
# 欧阳雨彤
# 刘誉飞
# 欧阳雨彤
# 罗卓彦
# 欧阳雨彤
# 王兆阳
# 欧阳雨彤
# 王湘源
# 欧阳雨彤
# 蔡雅清
# 苏彤彤
# 方玉杰
# 苏彤彤
# 彭英哲
# 苏彤彤
# 闫海玉
# 苏彤彤
# 李佳祥
# 苏彤彤
# 廖宏祖
# 苏彤彤
# 陈智宏
# 苏彤彤
# 顾海健
# 苏彤彤
# 何远洋
# 苏彤彤
# 吕喆行
# 苏彤彤
# 朱宇飞
# 苏彤彤
# 蒋卓洋
# 苏彤彤
# 李柏萱
# 苏彤彤
# 李凯新
# 苏彤彤
# 袁一啸
# 苏彤彤
# 温若尧
# 苏彤彤
# 司考
# 苏彤彤
# 牟俊奇
# 苏彤彤
# 欧阳雨彤
# 苏彤彤
# 苏彤彤
# 苏彤彤
# 沈小力
# 苏彤彤
# 徐丹颖
# 苏彤彤
# 耿青青
# 苏彤彤
# 杨捷
# 苏彤彤
# 刘幽远
# 苏彤彤
# 沈洋洋
# 苏彤彤
# 吴东昊
# 苏彤彤
# 白云浩
# 苏彤彤
# 谢志林
# 苏彤彤
# 朱婷婷
# 苏彤彤
# 曾晗
# 苏彤彤
# 朱启鹏
# 苏彤彤
# 张静涵
# 苏彤彤
# 秦巧琳
# 苏彤彤
# 马添毅
# 苏彤彤
# 余江伟
# 苏彤彤
# 李雨辰
# 苏彤彤
# 刘誉飞
# 苏彤彤
# 罗卓彦
# 苏彤彤
# 王兆阳
# 苏彤彤
# 王湘源
# 苏彤彤
# 蔡雅清
# 沈小力
# 方玉杰
# 沈小力
# 彭英哲
# 沈小力
# 闫海玉
# 沈小力
# 李佳祥
# 沈小力
# 廖宏祖
# 沈小力
# 陈智宏
# 沈小力
# 顾海健
# 沈小力
# 何远洋
# 沈小力
# 吕喆行
# 沈小力
# 朱宇飞
# 沈小力
# 蒋卓洋
# 沈小力
# 李柏萱
# 沈小力
# 李凯新
# 沈小力
# 袁一啸
# 沈小力
# 温若尧
# 沈小力
# 司考
# 沈小力
# 牟俊奇
# 沈小力
# 欧阳雨彤
# 沈小力
# 苏彤彤
# 沈小力
# 沈小力
# 沈小力
# 徐丹颖
# 沈小力
# 耿青青
# 沈小力
# 杨捷
# 沈小力
# 刘幽远
# 沈小力
# 沈洋洋
# 沈小力
# 吴东昊
# 沈小力
# 白云浩
# 沈小力
# 谢志林
# 沈小力
# 朱婷婷
# 沈小力
# 曾晗
# 沈小力
# 朱启鹏
# 沈小力
# 张静涵
# 沈小力
# 秦巧琳
# 沈小力
# 马添毅
# 沈小力
# 余江伟
# 沈小力
# 李雨辰
# 沈小力
# 刘誉飞
# 沈小力
# 罗卓彦
# 沈小力
# 王兆阳
# 沈小力
# 王湘源
# 沈小力
# 蔡雅清
# 徐丹颖
# 方玉杰
# 徐丹颖
# 彭英哲
# 徐丹颖
# 闫海玉
# 徐丹颖
# 李佳祥
# 徐丹颖
# 廖宏祖
# 徐丹颖
# 陈智宏
# 徐丹颖
# 顾海健
# 徐丹颖
# 何远洋
# 徐丹颖
# 吕喆行
# 徐丹颖
# 朱宇飞
# 徐丹颖
# 蒋卓洋
# 徐丹颖
# 李柏萱
# 徐丹颖
# 李凯新
# 徐丹颖
# 袁一啸
# 徐丹颖
# 温若尧
# 徐丹颖
# 司考
# 徐丹颖
# 牟俊奇
# 徐丹颖
# 欧阳雨彤
# 徐丹颖
# 苏彤彤
# 徐丹颖
# 沈小力
# 徐丹颖
# 徐丹颖
# 徐丹颖
# 耿青青
# 徐丹颖
# 杨捷
# 徐丹颖
# 刘幽远
# 徐丹颖
# 沈洋洋
# 徐丹颖
# 吴东昊
# 徐丹颖
# 白云浩
# 徐丹颖
# 谢志林
# 徐丹颖
# 朱婷婷
# 徐丹颖
# 曾晗
# 徐丹颖
# 朱启鹏
# 徐丹颖
# 张静涵
# 徐丹颖
# 秦巧琳
# 徐丹颖
# 马添毅
# 徐丹颖
# 余江伟
# 徐丹颖
# 李雨辰
# 徐丹颖
# 刘誉飞
# 徐丹颖
# 罗卓彦
# 徐丹颖
# 王兆阳
# 徐丹颖
# 王湘源
# 徐丹颖
# 蔡雅清
# 耿青青
# 方玉杰
# 耿青青
# 彭英哲
# 耿青青
# 闫海玉
# 耿青青
# 李佳祥
# 耿青青
# 廖宏祖
# 耿青青
# 陈智宏
# 耿青青
# 顾海健
# 耿青青
# 何远洋
# 耿青青
# 吕喆行
# 耿青青
# 朱宇飞
# 耿青青
# 蒋卓洋
# 耿青青
# 李柏萱
# 耿青青
# 李凯新
# 耿青青
# 袁一啸
# 耿青青
# 温若尧
# 耿青青
# 司考
# 耿青青
# 牟俊奇
# 耿青青
# 欧阳雨彤
# 耿青青
# 苏彤彤
# 耿青青
# 沈小力
# 耿青青
# 徐丹颖
# 耿青青
# 耿青青
# 耿青青
# 杨捷
# 耿青青
# 刘幽远
# 耿青青
# 沈洋洋
# 耿青青
# 吴东昊
# 耿青青
# 白云浩
# 耿青青
# 谢志林
# 耿青青
# 朱婷婷
# 耿青青
# 曾晗
# 耿青青
# 朱启鹏
# 耿青青
# 张静涵
# 耿青青
# 秦巧琳
# 耿青青
# 马添毅
# 耿青青
# 余江伟
# 耿青青
# 李雨辰
# 耿青青
# 刘誉飞
# 耿青青
# 罗卓彦
# 耿青青
# 王兆阳
# 耿青青
# 王湘源
# 耿青青
# 蔡雅清
# 蔡雅清
# 方玉杰
# 蔡雅清
# 彭英哲
# 蔡雅清
# 闫海玉
# 蔡雅清
# 李佳祥
# 蔡雅清
# 廖宏祖
# 蔡雅清
# 陈智宏
# 蔡雅清
# 顾海健
# 蔡雅清
# 何远洋
# 蔡雅清
# 吕喆行
# 蔡雅清
# 朱宇飞
# 蔡雅清
# 蒋卓洋
# 蔡雅清
# 李柏萱
# 蔡雅清
# 李凯新
# 蔡雅清
# 袁一啸
# 蔡雅清
# 温若尧
# 蔡雅清
# 司考
# 蔡雅清
# 牟俊奇
# 蔡雅清
# 欧阳雨彤
# 蔡雅清
# 苏彤彤
# 蔡雅清
# 沈小力
# 蔡雅清
# 徐丹颖
# 蔡雅清
# 耿青青
# 蔡雅清
# 杨捷
# 蔡雅清
# 刘幽远
# 蔡雅清
# 沈洋洋
# 蔡雅清
# 吴东昊
# 蔡雅清
# 白云浩
# 蔡雅清
# 谢志林
# 蔡雅清
# 朱婷婷
# 蔡雅清
# 曾晗
# 蔡雅清
# 朱启鹏
# 蔡雅清
# 张静涵
# 蔡雅清
# 秦巧琳
# 蔡雅清
# 马添毅
# 蔡雅清
# 余江伟
# 蔡雅清
# 李雨辰
# 蔡雅清
# 刘誉飞
# 蔡雅清
# 罗卓彦
# 蔡雅清
# 王兆阳
# 蔡雅清
# 王湘源
# 蔡雅清
# 蔡雅清
# 刘幽远
# 方玉杰
# 刘幽远
# 彭英哲
# 刘幽远
# 闫海玉
# 刘幽远
# 李佳祥
# 刘幽远
# 廖宏祖
# 刘幽远
# 陈智宏
# 刘幽远
# 顾海健
# 刘幽远
# 何远洋
# 刘幽远
# 吕喆行
# 刘幽远
# 朱宇飞
# 刘幽远
# 蒋卓洋
# 刘幽远
# 李柏萱
# 刘幽远
# 李凯新
# 刘幽远
# 袁一啸
# 刘幽远
# 温若尧
# 刘幽远
# 司考
# 刘幽远
# 牟俊奇
# 刘幽远
# 欧阳雨彤
# 刘幽远
# 苏彤彤
# 刘幽远
# 沈小力
# 刘幽远
# 徐丹颖
# 刘幽远
# 耿青青
# 刘幽远
# 杨捷
# 刘幽远
# 刘幽远
# 刘幽远
# 沈洋洋
# 刘幽远
# 吴东昊
# 刘幽远
# 白云浩
# 刘幽远
# 谢志林
# 刘幽远
# 朱婷婷
# 刘幽远
# 曾晗
# 刘幽远
# 朱启鹏
# 刘幽远
# 张静涵
# 刘幽远
# 秦巧琳
# 刘幽远
# 马添毅
# 刘幽远
# 余江伟
# 刘幽远
# 李雨辰
# 刘幽远
# 刘誉飞
# 刘幽远
# 罗卓彦
# 刘幽远
# 王兆阳
# 刘幽远
# 王湘源
# 刘幽远
# 蔡雅清
# 沈洋洋
# 方玉杰
# 沈洋洋
# 彭英哲
# 沈洋洋
# 闫海玉
# 沈洋洋
# 李佳祥
# 沈洋洋
# 廖宏祖
# 沈洋洋
# 陈智宏
# 沈洋洋
# 顾海健
# 沈洋洋
# 何远洋
# 沈洋洋
# 吕喆行
# 沈洋洋
# 朱宇飞
# 沈洋洋
# 蒋卓洋
# 沈洋洋
# 李柏萱
# 沈洋洋
# 李凯新
# 沈洋洋
# 袁一啸
# 沈洋洋
# 温若尧
# 沈洋洋
# 司考
# 沈洋洋
# 牟俊奇
# 沈洋洋
# 欧阳雨彤
# 沈洋洋
# 苏彤彤
# 沈洋洋
# 沈小力
# 沈洋洋
# 徐丹颖
# 沈洋洋
# 耿青青
# 沈洋洋
# 杨捷
# 沈洋洋
# 刘幽远
# 沈洋洋
# 沈洋洋
# 沈洋洋
# 吴东昊
# 沈洋洋
# 白云浩
# 沈洋洋
# 谢志林
# 沈洋洋
# 朱婷婷
# 沈洋洋
# 曾晗
# 沈洋洋
# 朱启鹏
# 沈洋洋
# 张静涵
# 沈洋洋
# 秦巧琳
# 沈洋洋
# 马添毅
# 沈洋洋
# 余江伟
# 沈洋洋
# 李雨辰
# 沈洋洋
# 刘誉飞
# 沈洋洋
# 罗卓彦
# 沈洋洋
# 王兆阳
# 沈洋洋
# 王湘源
# 沈洋洋
# 蔡雅清
# 吴东昊
# 方玉杰
# 吴东昊
# 彭英哲
# 吴东昊
# 闫海玉
# 吴东昊
# 李佳祥
# 吴东昊
# 廖宏祖
# 吴东昊
# 陈智宏
# 吴东昊
# 顾海健
# 吴东昊
# 何远洋
# 吴东昊
# 吕喆行
# 吴东昊
# 朱宇飞
# 吴东昊
# 蒋卓洋
# 吴东昊
# 李柏萱
# 吴东昊
# 李凯新
# 吴东昊
# 袁一啸
# 吴东昊
# 温若尧
# 吴东昊
# 司考
# 吴东昊
# 牟俊奇
# 吴东昊
# 欧阳雨彤
# 吴东昊
# 苏彤彤
# 吴东昊
# 沈小力
# 吴东昊
# 徐丹颖
# 吴东昊
# 耿青青
# 吴东昊
# 杨捷
# 吴东昊
# 刘幽远
# 吴东昊
# 沈洋洋
# 吴东昊
# 吴东昊
# 吴东昊
# 白云浩
# 吴东昊
# 谢志林
# 吴东昊
# 朱婷婷
# 吴东昊
# 曾晗
# 吴东昊
# 朱启鹏
# 吴东昊
# 张静涵
# 吴东昊
# 秦巧琳
# 吴东昊
# 马添毅
# 吴东昊
# 余江伟
# 吴东昊
# 李雨辰
# 吴东昊
# 刘誉飞
# 吴东昊
# 罗卓彦
# 吴东昊
# 王兆阳
# 吴东昊
# 王湘源
# 吴东昊
# 蔡雅清
# 白云浩
# 方玉杰
# 白云浩
# 彭英哲
# 白云浩
# 闫海玉
# 白云浩
# 李佳祥
# 白云浩
# 廖宏祖
# 白云浩
# 陈智宏
# 白云浩
# 顾海健
# 白云浩
# 何远洋
# 白云浩
# 吕喆行
# 白云浩
# 朱宇飞
# 白云浩
# 蒋卓洋
# 白云浩
# 李柏萱
# 白云浩
# 李凯新
# 白云浩
# 袁一啸
# 白云浩
# 温若尧
# 白云浩
# 司考
# 白云浩
# 牟俊奇
# 白云浩
# 欧阳雨彤
# 白云浩
# 苏彤彤
# 白云浩
# 沈小力
# 白云浩
# 徐丹颖
# 白云浩
# 耿青青
# 白云浩
# 杨捷
# 白云浩
# 刘幽远
# 白云浩
# 沈洋洋
# 白云浩
# 吴东昊
# 白云浩
# 白云浩
# 白云浩
# 谢志林
# 白云浩
# 朱婷婷
# 白云浩
# 曾晗
# 白云浩
# 朱启鹏
# 白云浩
# 张静涵
# 白云浩
# 秦巧琳
# 白云浩
# 马添毅
# 白云浩
# 余江伟
# 白云浩
# 李雨辰
# 白云浩
# 刘誉飞
# 白云浩
# 罗卓彦
# 白云浩
# 王兆阳
# 白云浩
# 王湘源
# 白云浩
# 蔡雅清
# 谢志林
# 方玉杰
# 谢志林
# 彭英哲
# 谢志林
# 闫海玉
# 谢志林
# 李佳祥
# 谢志林
# 廖宏祖
# 谢志林
# 陈智宏
# 谢志林
# 顾海健
# 谢志林
# 何远洋
# 谢志林
# 吕喆行
# 谢志林
# 朱宇飞
# 谢志林
# 蒋卓洋
# 谢志林
# 李柏萱
# 谢志林
# 李凯新
# 谢志林
# 袁一啸
# 谢志林
# 温若尧
# 谢志林
# 司考
# 谢志林
# 牟俊奇
# 谢志林
# 欧阳雨彤
# 谢志林
# 苏彤彤
# 谢志林
# 沈小力
# 谢志林
# 徐丹颖
# 谢志林
# 耿青青
# 谢志林
# 杨捷
# 谢志林
# 刘幽远
# 谢志林
# 沈洋洋
# 谢志林
# 吴东昊
# 谢志林
# 白云浩
# 谢志林
# 谢志林
# 谢志林
# 朱婷婷
# 谢志林
# 曾晗
# 谢志林
# 朱启鹏
# 谢志林
# 张静涵
# 谢志林
# 秦巧琳
# 谢志林
# 马添毅
# 谢志林
# 余江伟
# 谢志林
# 李雨辰
# 谢志林
# 刘誉飞
# 谢志林
# 罗卓彦
# 谢志林
# 王兆阳
# 谢志林
# 王湘源
# 谢志林
# 蔡雅清
# 朱婷婷
# 方玉杰
# 朱婷婷
# 彭英哲
# 朱婷婷
# 闫海玉
# 朱婷婷
# 李佳祥
# 朱婷婷
# 廖宏祖
# 朱婷婷
# 陈智宏
# 朱婷婷
# 顾海健
# 朱婷婷
# 何远洋
# 朱婷婷
# 吕喆行
# 朱婷婷
# 朱宇飞
# 朱婷婷
# 蒋卓洋
# 朱婷婷
# 李柏萱
# 朱婷婷
# 李凯新
# 朱婷婷
# 袁一啸
# 朱婷婷
# 温若尧
# 朱婷婷
# 司考
# 朱婷婷
# 牟俊奇
# 朱婷婷
# 欧阳雨彤
# 朱婷婷
# 苏彤彤
# 朱婷婷
# 沈小力
# 朱婷婷
# 徐丹颖
# 朱婷婷
# 耿青青
# 朱婷婷
# 杨捷
# 朱婷婷
# 刘幽远
# 朱婷婷
# 沈洋洋
# 朱婷婷
# 吴东昊
# 朱婷婷
# 白云浩
# 朱婷婷
# 谢志林
# 朱婷婷
# 朱婷婷
# 朱婷婷
# 曾晗
# 朱婷婷
# 朱启鹏
# 朱婷婷
# 张静涵
# 朱婷婷
# 秦巧琳
# 朱婷婷
# 马添毅
# 朱婷婷
# 余江伟
# 朱婷婷
# 李雨辰
# 朱婷婷
# 刘誉飞
# 朱婷婷
# 罗卓彦
# 朱婷婷
# 王兆阳
# 朱婷婷
# 王湘源
# 朱婷婷
# 蔡雅清
# 曾晗
# 方玉杰
# 曾晗
# 彭英哲
# 曾晗
# 闫海玉
# 曾晗
# 李佳祥
# 曾晗
# 廖宏祖
# 曾晗
# 陈智宏
# 曾晗
# 顾海健
# 曾晗
# 何远洋
# 曾晗
# 吕喆行
# 曾晗
# 朱宇飞
# 曾晗
# 蒋卓洋
# 曾晗
# 李柏萱
# 曾晗
# 李凯新
# 曾晗
# 袁一啸
# 曾晗
# 温若尧
# 曾晗
# 司考
# 曾晗
# 牟俊奇
# 曾晗
# 欧阳雨彤
# 曾晗
# 苏彤彤
# 曾晗
# 沈小力
# 曾晗
# 徐丹颖
# 曾晗
# 耿青青
# 曾晗
# 杨捷
# 曾晗
# 刘幽远
# 曾晗
# 沈洋洋
# 曾晗
# 吴东昊
# 曾晗
# 白云浩
# 曾晗
# 谢志林
# 曾晗
# 朱婷婷
# 曾晗
# 曾晗
# 曾晗
# 朱启鹏
# 曾晗
# 张静涵
# 曾晗
# 秦巧琳
# 曾晗
# 马添毅
# 曾晗
# 余江伟
# 曾晗
# 李雨辰
# 曾晗
# 刘誉飞
# 曾晗
# 罗卓彦
# 曾晗
# 王兆阳
# 曾晗
# 王湘源
# 曾晗
# 蔡雅清
# 朱启鹏
# 方玉杰
# 朱启鹏
# 彭英哲
# 朱启鹏
# 闫海玉
# 朱启鹏
# 李佳祥
# 朱启鹏
# 廖宏祖
# 朱启鹏
# 陈智宏
# 朱启鹏
# 顾海健
# 朱启鹏
# 何远洋
# 朱启鹏
# 吕喆行
# 朱启鹏
# 朱宇飞
# 朱启鹏
# 蒋卓洋
# 朱启鹏
# 李柏萱
# 朱启鹏
# 李凯新
# 朱启鹏
# 袁一啸
# 朱启鹏
# 温若尧
# 朱启鹏
# 司考
# 朱启鹏
# 牟俊奇
# 朱启鹏
# 欧阳雨彤
# 朱启鹏
# 苏彤彤
# 朱启鹏
# 沈小力
# 朱启鹏
# 徐丹颖
# 朱启鹏
# 耿青青
# 朱启鹏
# 杨捷
# 朱启鹏
# 刘幽远
# 朱启鹏
# 沈洋洋
# 朱启鹏
# 吴东昊
# 朱启鹏
# 白云浩
# 朱启鹏
# 谢志林
# 朱启鹏
# 朱婷婷
# 朱启鹏
# 曾晗
# 朱启鹏
# 朱启鹏
# 朱启鹏
# 张静涵
# 朱启鹏
# 秦巧琳
# 朱启鹏
# 马添毅
# 朱启鹏
# 余江伟
# 朱启鹏
# 李雨辰
# 朱启鹏
# 刘誉飞
# 朱启鹏
# 罗卓彦
# 朱启鹏
# 王兆阳
# 朱启鹏
# 王湘源
# 朱启鹏
# 蔡雅清
# 张静涵
# 方玉杰
# 张静涵
# 彭英哲
# 张静涵
# 闫海玉
# 张静涵
# 李佳祥
# 张静涵
# 廖宏祖
# 张静涵
# 陈智宏
# 张静涵
# 顾海健
# 张静涵
# 何远洋
# 张静涵
# 吕喆行
# 张静涵
# 朱宇飞
# 张静涵
# 蒋卓洋
# 张静涵
# 李柏萱
# 张静涵
# 李凯新
# 张静涵
# 袁一啸
# 张静涵
# 温若尧
# 张静涵
# 司考
# 张静涵
# 牟俊奇
# 张静涵
# 欧阳雨彤
# 张静涵
# 苏彤彤
# 张静涵
# 沈小力
# 张静涵
# 徐丹颖
# 张静涵
# 耿青青
# 张静涵
# 杨捷
# 张静涵
# 刘幽远
# 张静涵
# 沈洋洋
# 张静涵
# 吴东昊
# 张静涵
# 白云浩
# 张静涵
# 谢志林
# 张静涵
# 朱婷婷
# 张静涵
# 曾晗
# 张静涵
# 朱启鹏
# 张静涵
# 张静涵
# 张静涵
# 秦巧琳
# 张静涵
# 马添毅
# 张静涵
# 余江伟
# 张静涵
# 李雨辰
# 张静涵
# 刘誉飞
# 张静涵
# 罗卓彦
# 张静涵
# 王兆阳
# 张静涵
# 王湘源
# 张静涵
# 蔡雅清
# 秦巧琳
# 方玉杰
# 秦巧琳
# 彭英哲
# 秦巧琳
# 闫海玉
# 秦巧琳
# 李佳祥
# 秦巧琳
# 廖宏祖
# 秦巧琳
# 陈智宏
# 秦巧琳
# 顾海健
# 秦巧琳
# 何远洋
# 秦巧琳
# 吕喆行
# 秦巧琳
# 朱宇飞
# 秦巧琳
# 蒋卓洋
# 秦巧琳
# 李柏萱
# 秦巧琳
# 李凯新
# 秦巧琳
# 袁一啸
# 秦巧琳
# 温若尧
# 秦巧琳
# 司考
# 秦巧琳
# 牟俊奇
# 秦巧琳
# 欧阳雨彤
# 秦巧琳
# 苏彤彤
# 秦巧琳
# 沈小力
# 秦巧琳
# 徐丹颖
# 秦巧琳
# 耿青青
# 秦巧琳
# 杨捷
# 秦巧琳
# 刘幽远
# 秦巧琳
# 沈洋洋
# 秦巧琳
# 吴东昊
# 秦巧琳
# 白云浩
# 秦巧琳
# 谢志林
# 秦巧琳
# 朱婷婷
# 秦巧琳
# 曾晗
# 秦巧琳
# 朱启鹏
# 秦巧琳
# 张静涵
# 秦巧琳
# 秦巧琳
# 秦巧琳
# 马添毅
# 秦巧琳
# 余江伟
# 秦巧琳
# 李雨辰
# 秦巧琳
# 刘誉飞
# 秦巧琳
# 罗卓彦
# 秦巧琳
# 王兆阳
# 秦巧琳
# 王湘源
# 秦巧琳
# 蔡雅清
# 马添毅
# 方玉杰
# 马添毅
# 彭英哲
# 马添毅
# 闫海玉
# 马添毅
# 李佳祥
# 马添毅
# 廖宏祖
# 马添毅
# 陈智宏
# 马添毅
# 顾海健
# 马添毅
# 何远洋
# 马添毅
# 吕喆行
# 马添毅
# 朱宇飞
# 马添毅
# 蒋卓洋
# 马添毅
# 李柏萱
# 马添毅
# 李凯新
# 马添毅
# 袁一啸
# 马添毅
# 温若尧
# 马添毅
# 司考
# 马添毅
# 牟俊奇
# 马添毅
# 欧阳雨彤
# 马添毅
# 苏彤彤
# 马添毅
# 沈小力
# 马添毅
# 徐丹颖
# 马添毅
# 耿青青
# 马添毅
# 杨捷
# 马添毅
# 刘幽远
# 马添毅
# 沈洋洋
# 马添毅
# 吴东昊
# 马添毅
# 白云浩
# 马添毅
# 谢志林
# 马添毅
# 朱婷婷
# 马添毅
# 曾晗
# 马添毅
# 朱启鹏
# 马添毅
# 张静涵
# 马添毅
# 秦巧琳
# 马添毅
# 马添毅
# 马添毅
# 余江伟
# 马添毅
# 李雨辰
# 马添毅
# 刘誉飞
# 马添毅
# 罗卓彦
# 马添毅
# 王兆阳
# 马添毅
# 王湘源
# 马添毅
# 蔡雅清
# 余江伟
# 方玉杰
# 余江伟
# 彭英哲
# 余江伟
# 闫海玉
# 余江伟
# 李佳祥
# 余江伟
# 廖宏祖
# 余江伟
# 陈智宏
# 余江伟
# 顾海健
# 余江伟
# 何远洋
# 余江伟
# 吕喆行
# 余江伟
# 朱宇飞
# 余江伟
# 蒋卓洋
# 余江伟
# 李柏萱
# 余江伟
# 李凯新
# 余江伟
# 袁一啸
# 余江伟
# 温若尧
# 余江伟
# 司考
# 余江伟
# 牟俊奇
# 余江伟
# 欧阳雨彤
# 余江伟
# 苏彤彤
# 余江伟
# 沈小力
# 余江伟
# 徐丹颖
# 余江伟
# 耿青青
# 余江伟
# 杨捷
# 余江伟
# 刘幽远
# 余江伟
# 沈洋洋
# 余江伟
# 吴东昊
# 余江伟
# 白云浩
# 余江伟
# 谢志林
# 余江伟
# 朱婷婷
# 余江伟
# 曾晗
# 余江伟
# 朱启鹏
# 余江伟
# 张静涵
# 余江伟
# 秦巧琳
# 余江伟
# 马添毅
# 余江伟
# 余江伟
# 余江伟
# 李雨辰
# 余江伟
# 刘誉飞
# 余江伟
# 罗卓彦
# 余江伟
# 王兆阳
# 余江伟
# 王湘源
# 余江伟
# 蔡雅清
# 李雨辰
# 方玉杰
# 李雨辰
# 彭英哲
# 李雨辰
# 闫海玉
# 李雨辰
# 李佳祥
# 李雨辰
# 廖宏祖
# 李雨辰
# 陈智宏
# 李雨辰
# 顾海健
# 李雨辰
# 何远洋
# 李雨辰
# 吕喆行
# 李雨辰
# 朱宇飞
# 李雨辰
# 蒋卓洋
# 李雨辰
# 李柏萱
# 李雨辰
# 李凯新
# 李雨辰
# 袁一啸
# 李雨辰
# 温若尧
# 李雨辰
# 司考
# 李雨辰
# 牟俊奇
# 李雨辰
# 欧阳雨彤
# 李雨辰
# 苏彤彤
# 李雨辰
# 沈小力
# 李雨辰
# 徐丹颖
# 李雨辰
# 耿青青
# 李雨辰
# 杨捷
# 李雨辰
# 刘幽远
# 李雨辰
# 沈洋洋
# 李雨辰
# 吴东昊
# 李雨辰
# 白云浩
# 李雨辰
# 谢志林
# 李雨辰
# 朱婷婷
# 李雨辰
# 曾晗
# 李雨辰
# 朱启鹏
# 李雨辰
# 张静涵
# 李雨辰
# 秦巧琳
# 李雨辰
# 马添毅
# 李雨辰
# 余江伟
# 李雨辰
# 李雨辰
# 李雨辰
# 刘誉飞
# 李雨辰
# 罗卓彦
# 李雨辰
# 王兆阳
# 李雨辰
# 王湘源
# 李雨辰
# 蔡雅清
# 刘誉飞
# 方玉杰
# 刘誉飞
# 彭英哲
# 刘誉飞
# 闫海玉
# 刘誉飞
# 李佳祥
# 刘誉飞
# 廖宏祖
# 刘誉飞
# 陈智宏
# 刘誉飞
# 顾海健
# 刘誉飞
# 何远洋
# 刘誉飞
# 吕喆行
# 刘誉飞
# 朱宇飞
# 刘誉飞
# 蒋卓洋
# 刘誉飞
# 李柏萱
# 刘誉飞
# 李凯新
# 刘誉飞
# 袁一啸
# 刘誉飞
# 温若尧
# 刘誉飞
# 司考
# 刘誉飞
# 牟俊奇
# 刘誉飞
# 欧阳雨彤
# 刘誉飞
# 苏彤彤
# 刘誉飞
# 沈小力
# 刘誉飞
# 徐丹颖
# 刘誉飞
# 耿青青
# 刘誉飞
# 杨捷
# 刘誉飞
# 刘幽远
# 刘誉飞
# 沈洋洋
# 刘誉飞
# 吴东昊
# 刘誉飞
# 白云浩
# 刘誉飞
# 谢志林
# 刘誉飞
# 朱婷婷
# 刘誉飞
# 曾晗
# 刘誉飞
# 朱启鹏
# 刘誉飞
# 张静涵
# 刘誉飞
# 秦巧琳
# 刘誉飞
# 马添毅
# 刘誉飞
# 余江伟
# 刘誉飞
# 李雨辰
# 刘誉飞
# 刘誉飞
# 刘誉飞
# 罗卓彦
# 刘誉飞
# 王兆阳
# 刘誉飞
# 王湘源
# 刘誉飞
# 蔡雅清
# 罗卓彦
# 方玉杰
# 罗卓彦
# 彭英哲
# 罗卓彦
# 闫海玉
# 罗卓彦
# 李佳祥
# 罗卓彦
# 廖宏祖
# 罗卓彦
# 陈智宏
# 罗卓彦
# 顾海健
# 罗卓彦
# 何远洋
# 罗卓彦
# 吕喆行
# 罗卓彦
# 朱宇飞
# 罗卓彦
# 蒋卓洋
# 罗卓彦
# 李柏萱
# 罗卓彦
# 李凯新
# 罗卓彦
# 袁一啸
# 罗卓彦
# 温若尧
# 罗卓彦
# 司考
# 罗卓彦
# 牟俊奇
# 罗卓彦
# 欧阳雨彤
# 罗卓彦
# 苏彤彤
# 罗卓彦
# 沈小力
# 罗卓彦
# 徐丹颖
# 罗卓彦
# 耿青青
# 罗卓彦
# 杨捷
# 罗卓彦
# 刘幽远
# 罗卓彦
# 沈洋洋
# 罗卓彦
# 吴东昊
# 罗卓彦
# 白云浩
# 罗卓彦
# 谢志林
# 罗卓彦
# 朱婷婷
# 罗卓彦
# 曾晗
# 罗卓彦
# 朱启鹏
# 罗卓彦
# 张静涵
# 罗卓彦
# 秦巧琳
# 罗卓彦
# 马添毅
# 罗卓彦
# 余江伟
# 罗卓彦
# 李雨辰
# 罗卓彦
# 刘誉飞
# 罗卓彦
# 罗卓彦
# 罗卓彦
# 王兆阳
# 罗卓彦
# 王湘源
# 罗卓彦
# 蔡雅清
# 王兆阳
# 方玉杰
# 王兆阳
# 彭英哲
# 王兆阳
# 闫海玉
# 王兆阳
# 李佳祥
# 王兆阳
# 廖宏祖
# 王兆阳
# 陈智宏
# 王兆阳
# 顾海健
# 王兆阳
# 何远洋
# 王兆阳
# 吕喆行
# 王兆阳
# 朱宇飞
# 王兆阳
# 蒋卓洋
# 王兆阳
# 李柏萱
# 王兆阳
# 李凯新
# 王兆阳
# 袁一啸
# 王兆阳
# 温若尧
# 王兆阳
# 司考
# 王兆阳
# 牟俊奇
# 王兆阳
# 欧阳雨彤
# 王兆阳
# 苏彤彤
# 王兆阳
# 沈小力
# 王兆阳
# 徐丹颖
# 王兆阳
# 耿青青
# 王兆阳
# 杨捷
# 王兆阳
# 刘幽远
# 王兆阳
# 沈洋洋
# 王兆阳
# 吴东昊
# 王兆阳
# 白云浩
# 王兆阳
# 谢志林
# 王兆阳
# 朱婷婷
# 王兆阳
# 曾晗
# 王兆阳
# 朱启鹏
# 王兆阳
# 张静涵
# 王兆阳
# 秦巧琳
# 王兆阳
# 马添毅
# 王兆阳
# 余江伟
# 王兆阳
# 李雨辰
# 王兆阳
# 刘誉飞
# 王兆阳
# 罗卓彦
# 王兆阳
# 王兆阳
# 王兆阳
# 王湘源
# 王兆阳
# 蔡雅清
# 王湘源
# 方玉杰
# 王湘源
# 彭英哲
# 王湘源
# 闫海玉
# 王湘源
# 李佳祥
# 王湘源
# 廖宏祖
# 王湘源
# 陈智宏
# 王湘源
# 顾海健
# 王湘源
# 何远洋
# 王湘源
# 吕喆行
# 王湘源
# 朱宇飞
# 王湘源
# 蒋卓洋
# 王湘源
# 李柏萱
# 王湘源
# 李凯新
# 王湘源
# 袁一啸
# 王湘源
# 温若尧
# 王湘源
# 司考
# 王湘源
# 牟俊奇
# 王湘源
# 欧阳雨彤
# 王湘源
# 苏彤彤
# 王湘源
# 沈小力
# 王湘源
# 徐丹颖
# 王湘源
# 耿青青
# 王湘源
# 杨捷
# 王湘源
# 刘幽远
# 王湘源
# 沈洋洋
# 王湘源
# 吴东昊
# 王湘源
# 白云浩
# 王湘源
# 谢志林
# 王湘源
# 朱婷婷
# 王湘源
# 曾晗
# 王湘源
# 朱启鹏
# 王湘源
# 张静涵
# 王湘源
# 秦巧琳
# 王湘源
# 马添毅
# 王湘源
# 余江伟
# 王湘源
# 李雨辰
# 王湘源
# 刘誉飞
# 王湘源
# 罗卓彦
# 王湘源
# 王兆阳
# 王湘源
# 王湘源
# 王湘源
# 人脸认证的考察结果:
# 精度: 0.9024390243902439
# 回归率: 0.9024390243902439
# 特异性: 0.9975609756097561
# F1值: 0.9024390243902439

# %%
#人脸识别识别函数与判断函数定义
from torch.autograd import Variable
from PIL import Image, ImageDraw
resnet=torch.load("myresnet_final.pt")
names=[]
trans = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])

for item in os.listdir('mydata_cut'):
    names.append(item[9:])

def facial_recognition(path):
    resnet.eval()
    img=Image.open(path)
    img_tensor=trans(img)
    img_tensor=Variable(img_tensor.unsqueeze(0))
    output=resnet(img_tensor)
    _, train_predicted = torch.max(output.data, 1)
    print(names[train_predicted.item()])
    return names[train_predicted.item()]



def facial_verification(id,path):
    print(names[id])
    if facial_recognition(path)==names[id]:
        return 'True'
    else:
        return 'False'
    

#一张照片的人脸识别
import sys

def cv2_imread(file_path):
    cv_img=cv2.imdecode(np.fromfile(file_path,dtype=np.uint8),-1)
    return cv_img

finaldir=input('请输入测试对象图片路径：')
#查看路径下是否有照片
yn=cv2_imread(finaldir)
if yn is None:
    print('该路径下没有图片！')
    sys.exit(0)
#如果有图片：
image=Image.open(finaldir)
mtCNN = MTCNN(
    image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device
)
mtCNN(image,finaldir)
#输出人脸识别结果
print(facial_recognition(finaldir))
# Out:
# 请输入测试对象图片路径：q.jpg
# 秦巧琳
# 秦巧琳

# %%
#人脸识别识别函数与判断函数定义
from torch.autograd import Variable
from PIL import Image, ImageDraw
from facenet_pytorch import InceptionResnetV1,MTCNN, extract_face
import matplotlib.pyplot as plt

resnet=torch.load("myresnet5.pt")
names=[]
trans = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])

for item in os.listdir('mydata_cut'):
    names.append(item[9:])

mtcnn = MTCNN(image_size=160, margin=0, min_face_size=20,
    thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device)

# 裁剪照片函数
def cut_images(path):
    img = Image.open(path)
    if img.mode == 'RGBA':
        r, g, b, a = img.split()
        img = Image.merge("RGB", (r, g, b))
        #print(names[i],j+1," 4 to 3")
    elif img.mode != 'RGB':
        img = img.convert('RGB')
        #print(names[i],j+1," 1 to 3")
    boxes, probs, points = mtcnn.detect(img, landmarks=True)
    paths=[]
    for i, (box, point) in enumerate(zip(boxes, points)):
        #给小图起名字
        path2=path[:-4]+str(i)+'.jpg'
        paths.append(path2)
        #保存小图
        extract_face(img, box, image_size=160,save_path=path2)
    return paths
    
    
def facial_recognition(path):
    resnet.eval()
    img=Image.open(path)
    img_tensor=trans(img)
    img_tensor=Variable(img_tensor.unsqueeze(0))
    output=resnet(img_tensor)
    _, train_predicted = torch.max(output.data, 1)
    print(names[train_predicted.item()])
    return names[train_predicted.item()]

threshold=0.9
def facial_recognition_for3(new_path):
    paths=cut_images(new_path)
    if len(paths)==0:
        print('Sadly, MTCNN can\'t find any person.')
        return
    img=[]
    for i,path in enumerate(paths):
        plt.figure(figsize=(5,5))
        #plt.subplots_adjust(left=0.125, bottom=0.1, right=1.4, top=len(paths), wspace=0.2, hspace=0.2)
        img.append(Image.open(path))
        #ax=plt.subplot(len(paths),1,i+1)
        plt.imshow(img[i])
        plt.show()
        yes=input("Is it the person you want to recognize?(y/n)")
        if yes=='y' or yes=='Y':
            facial_recognition_open(img[i])
        else:
            print("Let's see next one!")
    print("All done.")


def facial_verification(id,path):
    print(names[id])
    if facial_recognition(path)==names[id]:
        return 'True'
    else:
        return 'False'
    
# 以下为实时检测功能
import sys

# 为了能够读写带中文路径的图片，重新定义cv2的读写函数
def cv2_imread(file_path):
    cv_img = cv2.imdecode(np.fromfile(file_path, dtype=np.uint8), -1)
    return cv_img


def cv2_imwrite(path, img):
    cv2.imencode('.jpg', img)[1].tofile(path)
    
    

def mtcnn_cut(img_path, save_path):
    img = Image.open(img_path)
    # 应用MTCNN对图片进行检测截取，并保存到指定路径下。
    mtCNN = MTCNN(
        image_size=160, margin=0, min_face_size=20,
        thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
        device=device
    )
    mtCNN(img, save_path=save_path)
       
    
def test_camera():
    cap = cv2.VideoCapture(0)
    while(1):
        ret, frame = cap.read()
        cv2.imshow("capture", frame)
        if cv2.waitKey(1) & 0xFF == ord('s'):
            cv2_imwrite("用户拍照上传图片.jpg", frame)
            break
    cap.release()
    cv2.destroyAllWindows()
    mtcnn_cut("用户拍照上传图片.jpg", "用户拍照上传图片.jpg")

choice = input("请输入想要的服务序号：A.人脸识别； B.人脸认证")

if choice == 'A' or choice == 'a':
    test_choice = input("请选择要测试的人脸图片获得途径: A.拍照； B.输入路径 C.多人检测")#
    if test_choice == 'A' or test_choice == 'a':
        test_camera()
        test_path = "用户拍照上传图片.jpg"
        print(facial_recognition(test_path))  # 进行人脸识别

    elif test_choice == 'B' or test_choice == 'b':
        test_path = input("请输入要测试的人脸图片路径：")

        # 测试该test_path下是否存在图片
        img = cv2_imread(test_path)
        if img is None:
            print("该路径下不存在图片！终止程序")
            sys.exit(0)

        mtcnn_cut(test_path, test_path)
        print(facial_recognition(test_path))  # 进行人脸识别
        
    elif test_choice == 'C' or test_choice == 'c':
        test_camera()
        

        mtcnn_cut(test_path, test_path)
        print(facial_recognition_for3(test_path))

    else:
        print("指令不存在！")
        sys.exit(0)


elif choice == 'B' or choice == 'b':
    test_choice = input("请选择要测试的人脸图片获得途径：A.拍照; B.输入路径")
    if test_choice == 'A' or test_choice == 'a':
        test_camera()
        test_path = "用户拍照上传图片.jpg"

    elif test_choice == 'B' or test_choice == 'b':
        test_path = input("请输入要测试的人脸路径：")
        # 测试该test_path下是否存在图片
        img = cv2_imread(test_path)
        if img is None:
            print("该路径下不存在图片！终止程序")
            sys.exit(0)
        mtcnn_cut(test_path, "test_mtcnn.jpg")  

    else:
        print("指令不存在！")
        sys.exit(0)

    # 便于用户提供想要测试的图片id号
    print("数据库中人脸图片及其序号为：")
    for i, name in enumerate(names):
        print(i, " ", name)

    id = input("请输入想要比对的人脸序号")
    print(facial_verification(int(id), test_path))  # 进行人脸认证
# Out:
# 请输入想要的服务序号：A.人脸识别； B.人脸认证a
# 请选择要测试的人脸图片获得途径: A.拍照； B.输入路径 C.多人检测a
# 徐丹颖
# 徐丹颖

# %%
#人脸识别识别函数与判断函数定义
from torch.autograd import Variable
from PIL import Image, ImageDraw
resnet=torch.load("myresnet_final.pt")
names=[]
trans = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    fixed_image_standardization
])

for item in os.listdir('mydata_cut'):
    names.append(item[9:])

def facial_recognition(path):
    resnet.eval()
    img=Image.open(path)
    img_tensor=trans(img)
    img_tensor=Variable(img_tensor.unsqueeze(0))
    output=resnet(img_tensor)
    _, train_predicted = torch.max(output.data, 1)
    print(names[train_predicted.item()])
    return names[train_predicted.item()]



def facial_verification(id,path):
    print(names[id])
    if facial_recognition(path)==names[id]:
        return 'True'
    else:
        return 'False'
    
# 以下为实时检测功能


import sys

# 为了能够读写带中文路径的图片，重新定义cv2的读写函数
def cv2_imread(file_path):
    cv_img = cv2.imdecode(np.fromfile(file_path, dtype=np.uint8), -1)
    return cv_img


def cv2_imwrite(path, img):
    cv2.imencode('.jpg', img)[1].tofile(path)
    
    

def mtcnn_cut(img_path, save_path):
    img = Image.open(img_path)
    # 应用MTCNN对图片进行检测截取，并保存到指定路径下。
    mtcnn(img, save_path=save_path)
    
def test_camera():
    cap = cv2.VideoCapture(0)
    while(1):
        ret, frame = cap.read()
        cv2.imshow("capture", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            cv2_imwrite("用户拍照上传图片.jpg", frame)
            break
    cap.release()
    cv2.destroyAllWindows()
    mtcnn_cut("用户拍照上传图片.jpg", "用户拍照上传图片.jpg")



choice = input("请输入想要的服务序号：A.人脸识别； B.人脸认证")

if choice == 'A' or choice == 'a':
    test_choice = input("请选择要测试的人脸图片获得途径: A.拍照； B.输入路径")
    if test_choice == 'A' or test_choice == 'a':
        test_camera()
        test_path = "用户拍照上传图片.jpg"

    elif test_choice == 'B' or test_choice == 'b':
        test_path = input("请输入要测试的人脸图片路径：")

        # 测试该test_path下是否存在图片
        img = cv2_imread(test_path)
        if img is None:
            print("该路径下不存在图片！终止程序")
            sys.exit(0)

        mtcnn_cut(test_path, test_path)

    else:
        print("指令不存在！")
        sys.exit(0)

    print(facial_recognition(test_path))  # 进行人脸识别

elif choice == 'B' or choice == 'b':
    test_choice = input("请选择要测试的人脸图片获得途径：A.拍照; B.输入路径")
    if test_choice == 'A' or test_choice == 'a':
        test_camera()
        test_path = "用户拍照上传图片.jpg"

    elif test_choice == 'B' or test_choice == 'b':
        test_path = input("请输入要测试的人脸路径：")
        # 测试该test_path下是否存在图片
        img = cv2_imread(test_path)
        if img is None:
            print("该路径下不存在图片！终止程序")
            sys.exit(0)
        mtcnn_cut(test_path, "test_mtcnn.jpg")  

    else:
        print("指令不存在！")
        sys.exit(0)

    # 便于用户提供想要测试的图片id号
    print("数据库中人脸图片及其序号为：")
    for i, name in enumerate(names):
        print(i, " ", name)

    id = input("请输入想要比对的人脸序号")
    print(facial_verification(int(id), test_path))  # 进行人脸认证
# Out:
# 请输入想要的服务序号：A.人脸识别； B.人脸认证a
# 请选择要测试的人脸图片获得途径: A.拍照； B.输入路径a
# 秦巧琳
# 秦巧琳

# %%
#对mtcnn加工后的训练集和测试集进行vgg预处理
def vgg_preprocess():
    path_train = "train_data_detect/"
    path_test = "test_data_detect/"
    train_list = os.listdir(path_train) 
    test_list = os.listdir(path_test) 
    process_train_path = "preprocessed_data_train/"
    process_test_path = "preprocessed_data_test/"
    for image in train_list:
        image_path = image
        in_path = path_train + image_path
        out_path = process_train_path + image_path
        img = cv2_imread(in_path)
        new_img = cv2.resize(img, (224, 224))
        img_name = out_path
        cv2_imwrite(img_name, new_img)
    for image in test_list:
        image_path = image
        in_path = path_test + image_path
        out_path = process_test_path + image_path
        img = cv2_imread(in_path)
        new_img = cv2.resize(img, (224, 224))
        img_name = out_path
        cv2_imwrite(img_name, new_img)         
        
#对训练集和测试集进行MTCNN加工,部分图片截取错误或挂服务，将手动截取
def mtcnncut():
    path_train = "train_data"
    path_test = "test_data"
    train_list = os.listdir(path_train) 
    test_list = os.listdir(path_test) 
    outpath = 'test_data_detect/'
    inpath = 'test_data/'
    mtcnn = MTCNN(keep_all=True)
    for i in range(0,39):
        find = inpath + test_list[i]
        save = outpath + test_list[i]
        img = Image.open(find)
        boxes, probs, points = mtcnn.detect(img,landmarks=True)
        img_draw = img.copy()
        draw = ImageDraw.Draw(img_draw)
        if(boxes is None or points is None):
            continue
        for i, (box, point) in enumerate(zip(boxes, points)):
            draw.rectangle(box.tolist(), width=5)
            for p in point:
                draw.rectangle((p-10).tolist()+(p+10).tolist(), width=10)
            extract_face(img, box, save_path=save)

# %%
names=['蔡雅清', '方玉杰', '彭英哲', '闫海玉', '李佳祥', '廖宏祖', 
       '陈智宏', '顾海健', '何远洋', '吕喆行', '朱宇飞', '蒋卓洋', 
       '李柏萱', '李凯新', '袁一啸', '温若尧', '司考', '牟俊奇', 
       '欧阳雨彤', '苏彤彤', '沈小力', '徐丹颖', '耿青青', '杨捷', 
       '刘幽远', '沈洋洋', '吴东昊', '白云浩', '谢志林', '朱婷婷', 
       '曾晗', '朱启鹏', '张静涵', '秦巧琳', '马添毅', '余江伟',
       '李雨辰', '刘誉飞', '罗卓彦', '王兆阳', '王湘源']

# %%
# 运行
# 加载处理后的数据库图片

# 对训练集预处理
trans = transforms.Compose([
    np.float32,
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.485, 0.456, 0.406], 
                         std = [0.229, 0.224, 0.225]),
    prewhiten
])

# 加载数据
dataset_cropped = datasets.ImageFolder('mytrain_cut', transform=trans)
loader_cropped = DataLoader(dataset_cropped,num_workers=workers,
    batch_size = 40,collate_fn=training.collate_pil
)
print("len(dataset_cropped)",len(dataset_cropped))  # 一共41*5=205张图片



# 使用在数据集'vggface2'预训练的模型facenet
resnet = torch.load('myresnet1.pt')
# 定义MTCNN变量
#mtcnn = MTCNN(image_size=160, margin=0, min_face_size=40,device=device)
mtcnn = MTCNN(
    image_size=160, margin=0, min_face_size=40,
    #thresholds=[0.6, 0.7, 0.7], factor=0.709, post_process=True,
    device=device
)


# 使用原模型计算训练集特征向量
embeddings = [] # 存放520张图片的特征向量
for i, (x, y) in enumerate(loader_cropped):
    x_tensor = torch.stack(x).to(device)
    embeddings.extend(resnet(x_tensor).detach().cpu())    # 使用resnet计算特征向量
    print('\rCalculate embeddings: Batch {} of {}'.format(i + 1, len(loader_cropped)), end='') 
print('len(embeddings)',len(embeddings))

# 求均值计算每个人的特征向量
embeddings_avg = []
for i in range(0,len(embeddings),5):
    embs = embeddings[i:i+5]  # 每五个特征向量求均值
    embeddings_avg.append(torch.mean(torch.stack([embs[0],embs[1],embs[2],embs[3],embs[4]]), 0)) 
print("len(embeddings_avg)",len(embeddings_avg))
print("特征向量维度为",embeddings_avg[0].shape)


# 为节省内存删除变量
del embeddings   
del dataset_cropped
del loader_cropped

torch.save(resnet,"myresnet_embed.pt")
# Out:
# len(dataset_cropped) 205
# Calculate embeddings: Batch 6 of 6len(embeddings) 205
# len(embeddings_avg) 41
# 特征向量维度为 torch.Size([41])

# %%
# 如果助教提供的用mtcnn处理后的图像大小为160*160，请运行该cell；否则跳过运行下一cell


# 人脸识别函数
def facial_recognition(t_path):
    img = Image.open(t_path).convert('RGB')        # 转换为3通道打开
    test_tensor = trans(img)
    resnet.eval()
    t_embedding = resnet(test_tensor.unsqueeze(0)) # 得到测试图片的特征向量
    # 计算该测试图片同训练图片的特征向量间距离
    distances = [(t_embedding-train_e).norm().item() for train_e in embeddings_avg]  # 距离列表
    pred_index = distances.index(min(distances))   # 找到最小距离
    del test_tensor
    return names[pred_index]


# 人脸认证函数
def facial_verification(id, t_path):      
    img = Image.open(t_path).convert('RGB')        # 转换为3通道打开
    test_tensor = trans(img)
    resnet.eval()
    t_embedding = resnet(test_tensor.unsqueeze(0)) # 得到测试图片的特征向量
    # 计算该测试图片同训练图片的特征向量间距离
    distance = (t_embedding-embeddings_avg[id]).norm().item()  # 计算测试图片同比对id之间的距离
    del test_tensor
    if(distance<0.7):    # 定义阈值
        return "True"
    else:
        return "False"

# %%
# 人脸识别评测代码    
import datetime

starttime = datetime.datetime.now()
right = 0
wrong = 0

for item in os.listdir("mytest_cut"):
    test_path = "mytest_cut"+"\\" + item
    print(item)
    if facial_recognition(test_path) in item:
        right += 1
    else:
        wrong += 1

accuracy = right / (right+wrong)
endtime = datetime.datetime.now()

print("人脸识别的考察结果：")
print("人脸识别的准确率是:", accuracy)
print("整个人脸识别的运行时间是：", (endtime-starttime).seconds, "s")
# Out:
# 何远洋_1.jpg
# 余江伟_1.jpg
# 刘幽远_1.jpg
# 刘誉飞_1.jpg
# 司考_1.jpg
# 吕喆行_1.jpg
# 吴东昊_1.jpg
# 廖宏祖_1.jpg
# 张静涵_1.jpg
# 彭英哲_1.jpg
# 徐丹颖_1.jpg
# 方玉杰_1.jpg
# 曾晗_1.jpg
# 朱启鹏_1.jpg
# 朱婷婷_1.jpg
# 朱宇飞_1.jpg
# 李佳祥_1.jpg
# 李凯新_1.jpg
# 李柏萱_1.jpg
# 李雨辰_1.jpg
# 杨捷_1.JPG
# 欧阳雨彤_1.jpg
# 沈小力_1.jpg
# 沈洋洋_1.jpg
# 温若尧_1.JPG
# 牟俊奇_1.jpg
# 王兆阳_1.jpg
# 王湘源_1.jpg
# 白云浩_1.jpg
# 秦巧琳_1.jpg
# 罗卓彦_1.jpg
# 耿青青_1.JPG
# 苏彤彤_1.jpg
# 蒋卓洋_1.jpg
# 蔡雅清_1.JPG
# 袁一啸_1.jpg
# 谢志林_1.jpg
# 闫海玉_1.jpg
# 陈智宏_1.jpg
# 顾海健_1.jpg
# 马添毅_1.jpg
# 人脸识别的考察结果：
# 人脸识别的准确率是: 0.6097560975609756
# 整个人脸识别的运行时间是： 3 s

# %%
'''
# 人脸认证评测代码 (自己修改了一点)  时间会很久。。
tp = 0
tn = 0
fp = 0
fn = 0

for name in names:
    print(name)                                          # !!!这里加了输出
    test_path = "mytest_cut/" + name + "_1.jpg"
    for id in range(len(names)):
        result = facial_verification(id, test_path)
        print(id,result)                                 # !!!这里加了输出
        if name == names[id] and result == "True":
            tp +=1
        elif name == names[id] and result == "False":
            fn += 1
        elif name != names[id] and result == "False":
            tn += 1
        else:
            fp += 1

print("人脸认证的考察结果:")
print("精度:", tp/(tp+fp))
print("回归率:", tp/(tp+fn))
print("特异性:", tn/(tn+fp))
print("F1值:", 2*tp/(2*tp+fp+fn))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-658fc2d2be8b> in <module>
#       5 fn = 0
#       6
# ----> 7 for name in names:
#       8     print(name)                                          # !!!这里加了输出
#       9     test_path = "mytest_cut/" + name + "_1.jpg"
#
# NameError: name 'names' is not defined
